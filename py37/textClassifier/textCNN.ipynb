# %%
import os
import csv
import time
import datetime
import random
import json

from collections import Counter
from math import sqrt

import gensim
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score

# %%
# 配置参数

class TrainingConfig(object):
    epoches = 5
    evaluateEvery = 100
    checkpointEvery = 100
    learningRate = 0.001
    
class ModelConfig(object):
    embeddingSize = 200
    numFilters = 128

    filterSizes = [2, 3, 4, 5]
    dropoutKeepProb = 0.5
    l2RegLambda = 0.0
    
class Config(object):
    sequenceLength = 200  # 取了所有序列长度的均值
    batchSize = 128
    
    dataSource = "../data/preProcess/labeledTrain.csv"
    
    stopWordSource = "../data/english"
    
    numClasses = 1  # 二分类设置为1，多分类设置为类别的数目
    
    rate = 0.8  # 训练集的比例
    
    training = TrainingConfig()
    
    model = ModelConfig()

    
# 实例化配置参数对象
config = Config()

# %%
# 数据预处理的类，生成训练集和测试集

class Dataset(object):
    def __init__(self, config):
        self.config = config
        self._dataSource = config.dataSource
        self._stopWordSource = config.stopWordSource  
        
        self._sequenceLength = config.sequenceLength  # 每条输入的序列处理为定长
        self._embeddingSize = config.model.embeddingSize
        self._batchSize = config.batchSize
        self._rate = config.rate
        
        self._stopWordDict = {}
        
        self.trainReviews = []
        self.trainLabels = []
        
        self.evalReviews = []
        self.evalLabels = []
        
        self.wordEmbedding =None
        
        self.labelList = []
        
    def _readData(self, filePath):
        """
        从csv文件中读取数据集
        """
        
        df = pd.read_csv(filePath)
        
        if self.config.numClasses == 1:
            labels = df["sentiment"].tolist()
        elif self.config.numClasses > 1:
            labels = df["rate"].tolist()
            
        review = df["review"].tolist()
        reviews = [line.strip().split() for line in review]

        return reviews, labels
    
    def _labelToIndex(self, labels, label2idx):
        """
        将标签转换成索引表示
        """
        labelIds = [label2idx[label] for label in labels]
        return labelIds
    
    def _wordToIndex(self, reviews, word2idx):
        """
        将词转换成索引
        """
        reviewIds = [[word2idx.get(item, word2idx["UNK"]) for item in review] for review in reviews]
        return reviewIds
        
    def _genTrainEvalData(self, x, y, word2idx, rate):
        """
        生成训练集和验证集
        """
        reviews = []
        for review in x:
            if len(review) >= self._sequenceLength:
                reviews.append(review[:self._sequenceLength])
            else:
                reviews.append(review + [word2idx["PAD"]] * (self._sequenceLength - len(review)))
            
        trainIndex = int(len(x) * rate)
        
        trainReviews = np.asarray(reviews[:trainIndex], dtype="int64")
        trainLabels = np.array(y[:trainIndex], dtype="float32")
        
        evalReviews = np.asarray(reviews[trainIndex:], dtype="int64")
        evalLabels = np.array(y[trainIndex:], dtype="float32")

        return trainReviews, trainLabels, evalReviews, evalLabels
        
    def _genVocabulary(self, reviews, labels):
        """
        生成词向量和词汇-索引映射字典，可以用全数据集
        """
        
        allWords = [word for review in reviews for word in review]
        
        # 去掉停用词
        subWords = [word for word in allWords if word not in self.stopWordDict]
        
        wordCount = Counter(subWords)  # 统计词频
        sortWordCount = sorted(wordCount.items(), key=lambda x: x[1], reverse=True)
        
        # 去除低频词
        words = [item[0] for item in sortWordCount if item[1] >= 5]
        
        vocab, wordEmbedding = self._getWordEmbedding(words)
        self.wordEmbedding = wordEmbedding
        
        word2idx = dict(zip(vocab, list(range(len(vocab)))))
        
        uniqueLabel = list(set(labels))
        label2idx = dict(zip(uniqueLabel, list(range(len(uniqueLabel)))))
        self.labelList = list(range(len(uniqueLabel)))
        
        # 将词汇-索引映射表保存为json数据，之后做inference时直接加载来处理数据
        with open("../data/wordJson/word2idx.json", "w", encoding="utf-8") as f:
            json.dump(word2idx, f)
        
        with open("../data/wordJson/label2idx.json", "w", encoding="utf-8") as f:
            json.dump(label2idx, f)
        
        return word2idx, label2idx
            
    def _getWordEmbedding(self, words):
        """
        按照我们的数据集中的单词取出预训练好的word2vec中的词向量
        """
        
        wordVec = gensim.models.KeyedVectors.load_word2vec_format("../word2vec/word2Vec.bin", binary=True)
        vocab = []
        wordEmbedding = []
        
        # 添加 "pad" 和 "UNK", 
        vocab.append("PAD")
        vocab.append("UNK")
        wordEmbedding.append(np.zeros(self._embeddingSize))
        wordEmbedding.append(np.random.randn(self._embeddingSize))
        
        for word in words:
            try:
                vector = wordVec.wv[word]
                vocab.append(word)
                wordEmbedding.append(vector)
            except:
                print(word + "不存在于词向量中")
                
        return vocab, np.array(wordEmbedding)
    
    def _readStopWord(self, stopWordPath):
        """
        读取停用词
        """
        
        with open(stopWordPath, "r") as f:
            stopWords = f.read()
            stopWordList = stopWords.splitlines()
            # 将停用词用列表的形式生成，之后查找停用词时会比较快
            self.stopWordDict = dict(zip(stopWordList, list(range(len(stopWordList)))))
            
    def dataGen(self):
        """
        初始化训练集和验证集
        """
        
        # 初始化停用词
        self._readStopWord(self._stopWordSource)
        
        # 初始化数据集
        reviews, labels = self._readData(self._dataSource)
        
        # 初始化词汇-索引映射表和词向量矩阵
        word2idx, label2idx = self._genVocabulary(reviews, labels)
        
        # 将标签和句子数值化
        labelIds = self._labelToIndex(labels, label2idx)
        reviewIds = self._wordToIndex(reviews, word2idx)
        
        # 初始化训练集和测试集
        trainReviews, trainLabels, evalReviews, evalLabels = self._genTrainEvalData(reviewIds, labelIds, word2idx, self._rate)
        self.trainReviews = trainReviews
        self.trainLabels = trainLabels
        
        self.evalReviews = evalReviews
        self.evalLabels = evalLabels
        
        
data = Dataset(config)
data.dataGen()
data
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:129: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# youre不存在于词向量中
# youll不存在于词向量中
# theyre不存在于词向量中
# youve不存在于词向量中
# werent不存在于词向量中
# youd不存在于词向量中
# hasnt不存在于词向量中
# shouldnt不存在于词向量中
# weve不存在于词向量中
# theyve不存在于词向量中
# 1010不存在于词向量中
# wouldve不存在于词向量中
# hed不存在于词向量中
# andor不存在于词向量中
# couldve不存在于词向量中
# 810不存在于词向量中
# itthe不存在于词向量中
# 710不存在于词向量中
# theyd不存在于词向量中
# writerdirector不存在于词向量中
# moviei不存在于词向量中
# iti不存在于词向量中
# theyll不存在于词向量中
# 310不存在于词向量中
# 410不存在于词向量中
# 910不存在于词向量中
# itll不存在于词向量中
# lees不存在于词向量中
# familys不存在于词向量中
# disneys不存在于词向量中
# filmi不存在于词向量中
# 210不存在于词向量中
# shouldve不存在于词向量中
# *12不存在于词向量中
# shakespeares不存在于词向量中
# hitlers不存在于词向量中
# brazil:不存在于词向量中
# freddys不存在于词向量中
# fords不存在于词向量中
# storys不存在于词向量中
# ohara不存在于词向量中
# stewarts不存在于词向量中
# kellys不存在于词向量中
# scotts不存在于词向量中
# tonys不存在于词向量中
# itthis不存在于词向量中
# keatons不存在于词向量中
# rosemarys不存在于词向量中
# ches不存在于词向量中
# themthe不存在于词向量中
# timethe不存在于词向量中
# branaghs不存在于词向量中
# mustve不存在于词向量中
# kubricks不存在于词向量中
# hitchcocks不存在于词向量中
# lynchs不存在于词向量中
# bakshis不存在于词向量中
# whove不存在于词向量中
# allthe不存在于词向量中
# whod不存在于词向量中
# itit不存在于词向量中
# smiths不存在于词向量中
# obrien不存在于词向量中
# palmas不存在于词向量中
# cravens不存在于词向量中
# timei不存在于词向量中
# movieit不存在于词向量中
# hartleys不存在于词向量中
# waythe不存在于词向量中
# altmans不存在于词向量中
# itbut不存在于词向量中
# himthe不存在于词向量中
# storythe不存在于词向量中
# taime不存在于词向量中
# methe不存在于词向量中
# filmthis不存在于词向量中
# verhoevens不存在于词向量中
# filmit不存在于词向量中
# romeros不存在于词向量中
# eastwoods不存在于词向量中
# countrys不存在于词向量中
# oneill不存在于词向量中
# miyazakis不存在于词向量中
# sinatras不存在于词向量中
# 010不存在于词向量中
# harrys不存在于词向量中
# everybodys不存在于词向量中
# victorias不存在于词向量中
# movieits不存在于词向量中
# movieand不存在于词向量中
# citys不存在于词向量中
# cmon不存在于词向量中
# thatll不存在于词向量中
# goodthe不存在于词向量中
# itd不存在于词向量中
# pauls不存在于词向量中
# hisher不存在于词向量中
# spielbergs不存在于词向量中
# streisands不存在于词向量中
# imdbs不存在于词向量中
# moviethis不存在于词向量中
# otoole不存在于词向量中
# heshe不存在于词向量中
# itits不存在于词向量中
# gilligans不存在于词向量中
# pacinos不存在于词向量中
# teds不存在于词向量中
# actorsactresses不存在于词向量中
# ladys不存在于词向量中
# directorwriter不存在于词向量中
# singin不存在于词向量中
# fulcis不存在于词向量中
# bens不存在于词向量中
# osullivan不存在于词向量中
# therethe不存在于词向量中
# badthe不存在于词向量中
# onethe不存在于词向量中
# austens不存在于词向量中
# alli不存在于词向量中
# herethe不存在于词向量中
# wellthe不存在于词向量中
# elviras不存在于词向量中
# cusacks不存在于词向量中
# arthurs不存在于词向量中
# nobodys不存在于词向量中
# brandos不存在于词向量中
# taylors不存在于词向量中
# goldsworthys不存在于词向量中
# betterthe不存在于词向量中
# toothe不存在于词向量中
# thisthe不存在于词向量中
# lifethe不存在于词向量中
# jims不存在于词向量中
# londons不存在于词向量中
# itif不存在于词向量中
# youngs不存在于词向量中
# joes不存在于词向量中
# manns不存在于词向量中
# burtons不存在于词向量中
# toms不存在于词向量中
# kurosawas不存在于词向量中
# horrorthriller不存在于词向量中
# johnsons不存在于词向量中
# thati不存在于词向量中
# santas不存在于词向量中
# dereks不存在于词向量中
# oneal不存在于词向量中
# stanwycks不存在于词向量中
# onthe不存在于词向量中
# lincolns不存在于词向量中
# soderberghs不存在于词向量中
# isthe不存在于词向量中
# powells不存在于词向量中
# moviesthe不存在于词向量中
# outthe不存在于词向量中
# dawsons不存在于词向量中
# thisi不存在于词向量中
# caines不存在于词向量中
# moviethere不存在于词向量中
# chaplins不存在于词向量中
# logans不存在于词向量中
# stallones不存在于词向量中
# erics不存在于词向量中
# worldthe不存在于词向量中
# flynns不存在于词向量中
# andys不存在于词向量中
# herthe不存在于词向量中
# againthe不存在于词向量中
# tolkiens不存在于词向量中
# funnyi不存在于词向量中
# fromthe不存在于词向量中
# themthis不存在于词向量中
# marys不存在于词向量中
# funnythe不存在于词向量中
# moviebut不存在于词向量中
# oni不存在于词向量中
# capotes不存在于词向量中
# henrys不存在于词向量中
# antonionis不存在于词向量中
# sirks不存在于词向量中
# jackies不存在于词向量中
# annas不存在于词向量中
# charactersthe不存在于词向量中
# rolethe不存在于词向量中
# brontes不存在于词向量中
# ;-不存在于词向量中
# yorks不存在于词向量中
# neednt不存在于词向量中
# anns不存在于词向量中
# goodi不存在于词向量中
# sutherlands不存在于词向量中
# vonneguts不存在于词向量中
# sullivans不存在于词向量中
# glovers不存在于词向量中
# 510不存在于词向量中
# russells不存在于词向量中
# satans不存在于词向量中
# morethe不存在于词向量中
# mightve不存在于词向量中
# washingtons不存在于词向量中
# lukes不存在于词向量中
# macarthurs不存在于词向量中
# ***12不存在于词向量中
# oclock不存在于词向量中
# 610不存在于词向量中
# polanskis不存在于词向量中
# gilliams不存在于词向量中
# timesthe不存在于词向量中
# dannys不存在于词向量中
# drews不存在于词向量中
# societys不存在于词向量中
# itand不存在于词向量中
# carreys不存在于词向量中
# isi不存在于词向量中
# madonnas不存在于词向量中
# companys不存在于词向量中
# plotthe不存在于词向量中
# screenthe不存在于词向量中
# zizeks不存在于词向量中
# rachels不存在于词向量中
# endthe不存在于词向量中
# itin不存在于词向量中
# endi不存在于词向量中
# scorseses不存在于词向量中
# filmbut不存在于词向量中
# girlfight不存在于词向量中
# imdbcom不存在于词向量中
# beattys不存在于词向量中
# themi不存在于词向量中
# shaws不存在于词向量中
# aboutthe不存在于词向量中
# garbos不存在于词向量中
# wayi不存在于词向量中
# scenesthe不存在于词向量中
# seenthe不存在于词向量中
# threes不存在于词向量中
# minutesthe不存在于词向量中
# mgms不存在于词向量中
# premingers不存在于词向量中
# 7510不存在于词向量中
# carlas不存在于词向量中
# langs不存在于词向量中
# betties不存在于词向量中
# merk不存在于词向量中
# filmif不存在于词向量中
# dangelo不存在于词向量中
# lifei不存在于词向量中
# penns不存在于词向量中
# cuckoos不存在于词向量中
# upthe不存在于词向量中
# clarks不存在于词向量中
# rochesters不存在于词向量中
# seriesthe不存在于词向量中
# oliviers不存在于词向量中
# als不存在于词向量中
# wholl不存在于词向量中
# bethe不存在于词向量中
# parkers不存在于词向量中
# badi不存在于词向量中
# lugosis不存在于词向量中
# millers不存在于词向量中
# hoffmans不存在于词向量中
# matthaus不存在于词向量中
# rockin不存在于词向量中
# walkens不存在于词向量中
# actionadventure不存在于词向量中
# filmand不存在于词向量中
# hardys不存在于词向量中
# eddies不存在于词向量中
# 8510不存在于词向量中
# kyles不存在于词向量中
# supermans不存在于词向量中
# harlins不存在于词向量中
# bos不存在于词向量中
# fullers不存在于词向量中
# kates不存在于词向量中
# adv不存在于词向量中
# moviesthis不存在于词向量中
# storyi不存在于词向量中
# mummys不存在于词向量中
# filma不存在于词向量中
# johnnys不存在于词向量中
# cohens不存在于词向量中
# gordons不存在于词向量中
# thompsons不存在于词向量中
# movieif不存在于词向量中
# freemans不存在于词向量中
# dexters不存在于词向量中
# cains不存在于词向量中
# sp不存在于词向量中
# welli不存在于词向量中
# lilys不存在于词向量中
# goauld不存在于词向量中
# anybodys不存在于词向量中
# fondas不存在于词向量中
# lennons不存在于词向量中
# characterthe不存在于词向量中
# det不存在于词向量中
# gilleys不存在于词向量中
# etcthe不存在于词向量中
# moviea不存在于词向量中
# annes不存在于词向量中
# eighttitle不存在于词向量中
# muchthe不存在于词向量中
# onei不存在于词向量中
# porkys不存在于词向量中
# jrs不存在于词向量中
# damato不存在于词向量中
# filmin不存在于词向量中
# brosnans不存在于词向量中
# rukhs不存在于词向量中
# levins不存在于词向量中
# alexs不存在于词向量中
# visiteurs不存在于词向量中
# crashers不存在于词向量中
# paulies不存在于词向量中
# nancys不存在于词向量中
# nicholsons不存在于词向量中
# woodys不存在于词向量中
# emmas不存在于词向量中
# panahis不存在于词向量中
# jerrys不存在于词向量中
# daythe不存在于词向量中
# wagners不存在于词向量中
# filmsthe不存在于词向量中
# maughams不存在于词向量中
# storythis不存在于词向量中
# dixons不存在于词向量中
# ollies不存在于词向量中
# alices不存在于词向量中
# bruces不存在于词向量中
# bolls不存在于词向量中
# bikos不存在于词向量中
# japans不存在于词向量中
# widmarks不存在于词向量中
# novaks不存在于词向量中
# englands不存在于词向量中
# familythe不存在于词向量中
# wasi不存在于词向量中
# actingthe不存在于词向量中
# youthe不存在于词向量中
# carters不存在于词向量中
# movieso不存在于词向量中
# $10000不存在于词向量中
# gibsons不存在于词向量中
# watchthe不存在于词向量中
# lundgrens不存在于词向量中
# camerons不存在于词向量中
# itthere不存在于词向量中
# rohmers不存在于词向量中
# workthe不存在于词向量中
# thirdly不存在于词向量中
# notthe不存在于词向量中
# attenboroughs不存在于词向量中
# viscontis不存在于词向量中
# frankies不存在于词向量中
# actoractress不存在于词向量中
# cormans不存在于词向量中
# perrys不存在于词向量中
# morgans不存在于词向量中
# moviesi不存在于词向量中
# hestons不存在于词向量中
# lovehate不存在于词向量中
# christys不存在于词向量中
# lumets不存在于词向量中
# lis不存在于词向量中
# anywaythe不存在于词向量中
# corbetts不存在于词向量中
# filmso不存在于词向量中
# againi不存在于词向量中
# connerys不存在于词向量中
# christs不存在于词向量中
# falks不存在于词向量中
# timethis不存在于词向量中
# jabbas不存在于词向量中
# timons不存在于词向量中
# streeps不存在于词向量中
# fishburnes不存在于词向量中
# khouris不存在于词向量中
# maries不存在于词向量中
# pecks不存在于词向量中
# thoughthe不存在于词向量中
# peckinpahs不存在于词向量中
# poes不存在于词向量中
# quinns不存在于词向量中
# wilders不存在于词向量中
# karloffs不存在于词向量中
# betteri不存在于词向量中
# universals不存在于词向量中
# neds不存在于词向量中
# goodbut不存在于词向量中
# funi不存在于词向量中
# didthe不存在于词向量中
# heri不存在于词向量中
# naschys不存在于词向量中
# filmthere不存在于词向量中
# ita不存在于词向量中
# putain不存在于词向量中
# oshea不存在于词向量中
# sidneys不存在于词向量中
# timmys不存在于词向量中
# argentos不存在于词向量中
# filmmy不存在于词向量中
# bbcs不存在于词向量中
# showthe不存在于词向量中
# tarantinos不存在于词向量中
# audiencethe不存在于词向量中
# wrongthe不存在于词向量中
# kazans不存在于词向量中
# dominos不存在于词向量中
# barkers不存在于词向量中
# bergmans不存在于词向量中
# lesters不存在于词向量中
# felixs不存在于词向量中
# somebodys不存在于词向量中
# gannons不存在于词向量中
# wendys不存在于词向量中
# madethe不存在于词向量中
# no1不存在于词向量中
# youi不存在于词向量中
# dont!不存在于词向量中
# martinos不存在于词向量中
# newmans不存在于词向量中
# tooi不存在于词向量中
# moviein不存在于词向量中
# mabels不存在于词向量中
# rien不存在于词向量中
# alisons不存在于词向量中
# australias不存在于词向量中
# filmits不存在于词向量中
# seeni不存在于词向量中
# amazoncom不存在于词向量中
# herei不存在于词向量中
# crowes不存在于词向量中
# lifethis不存在于词向量中
# ityou不存在于词向量中
# wellit不存在于词向量中
# seventitle不存在于词向量中
# greatthe不存在于词向量中
# macys不存在于词向量中
# itwhat不存在于词向量中
# donnas不存在于词向量中
# jimmys不存在于词向量中
# razors不存在于词向量中
# geddes不存在于词向量中
# duvalls不存在于词向量中
# babys不存在于词向量中
# sarahs不存在于词向量中
# endthis不存在于词向量中
# wrongi不存在于词向量中
# ritters不存在于词向量中
# leos不存在于词向量中
# steves不存在于词向量中
# petes不存在于词向量中
# fallons不存在于词向量中
# filmsi不存在于词向量中
# candys不存在于词向量中
# thisthis不存在于词向量中
# fellinis不存在于词向量中
# gershwins不存在于词向量中
# oconnor不存在于词向量中
# tealc不存在于词向量中
# manthe不存在于词向量中
# steiners不存在于词向量中
# abcs不存在于词向量中
# fishers不存在于词向量中
# roegs不存在于词向量中
# joeys不存在于词向量中
# disappointedthe不存在于词向量中
# comedys不存在于词向量中
# timein不存在于词向量中
# poseys不存在于词向量中
# itas不存在于词向量中
# unfilmable不存在于词向量中
# guevaras不存在于词向量中
# wilsons不存在于词向量中
# experiencethe不存在于词向量中
# brontës不存在于词向量中
# alans不存在于词向量中
# lilas不存在于词向量中
# therei不存在于词向量中
# belushis不存在于词向量中
# carells不存在于词向量中
# movieyou不存在于词向量中
# showi不存在于词向量中
# tracys不存在于词向量中
# eberts不存在于词向量中
# jennifers不存在于词向量中
# methis不存在于词向量中
# pointthe不存在于词向量中
# hepburns不存在于词向量中
# roys不存在于词向量中
# ritchies不存在于词向量中
# otherthe不存在于词向量中
# luzhins不存在于词向量中
# noti不存在于词向量中
# batmans不存在于词向量中
# thingi不存在于词向量中
# leonards不存在于词向量中
# greenaways不存在于词向量中
# hustons不存在于词向量中
# tarzans不存在于词向量中
# 2the不存在于词向量中
# harts不存在于词向量中
# versionthe不存在于词向量中
# susans不存在于词向量中
# lemmons不存在于词向量中
# burtynskys不存在于词向量中
# kiplings不存在于词向量中
# kaufmans不存在于词向量中
# nowi不存在于词向量中
# sic不存在于词向量中
# godards不存在于词向量中
# peoplethe不存在于词向量中
# dothe不存在于词向量中
# sebergs不存在于词向量中
# gandhis不存在于词向量中
# snitchd不存在于词向量中
# everythings不存在于词向量中
# einsteins不存在于词向量中
# stillers不存在于词向量中
# hoopers不存在于词向量中
# wellthis不存在于词向量中
# celestes不存在于词向量中
# cushings不存在于词向量中
# corsaut不存在于词向量中
# placethe不存在于词向量中
# eitherthe不存在于词向量中
# crapi不存在于词向量中
# bournes不存在于词向量中
# iberia不存在于词向量中
# itso不存在于词向量中
# oconor不存在于词向量中
# eitheri不存在于词向量中
# harlows不存在于词向量中
# odonnell不存在于词向量中
# farrells不存在于词向量中
# grendels不存在于词向量中
# lintrus不存在于词向量中
# movieone不存在于词向量中
# reasonthe不存在于词向量中
# modestys不存在于词向量中
# hudsons不存在于词向量中
# boyles不存在于词向量中
# realthe不存在于词向量中
# josephs不存在于词向量中
# hydes不存在于词向量中
# muchi不存在于词向量中
# seriesi不存在于词向量中
# gables不存在于词向量中
# rooneys不存在于词向量中
# moviewell不存在于词向量中
# boringi不存在于词向量中
# filmsthis不存在于词向量中
# astaires不存在于词向量中
# niros不存在于词向量中
# leones不存在于词向量中
# oconnell不存在于词向量中
# mamets不存在于词向量中
# herebut不存在于词向量中
# humanitys不存在于词向量中
# hilariousthe不存在于词向量中
# lewiss不存在于词向量中
# worldi不存在于词向量中
# himand不存在于词向量中
# pasolinis不存在于词向量中
# yetis不存在于词向量中
# partthe不存在于词向量中
# familyi不存在于词向量中
# ryans不存在于词向量中
# itselfi不存在于词向量中
# stroker不存在于词向量中
# rolesthe不存在于词向量中
# scriptthe不存在于词向量中
# thatthis不存在于词向量中
# tpol不存在于词向量中
# foxs不存在于词向量中
# jamess不存在于词向量中
# fassbinders不存在于词向量中
# beforethe不存在于词向量中
# decameron不存在于词向量中
# kims不存在于词向量中
# antwones不存在于词向量中
# pixars不存在于词向量中
# kristoffersons不存在于词向量中
# oneand不存在于词向量中
# casethe不存在于词向量中
# onthis不存在于词向量中
# moviedont不存在于词向量中
# cagneys不存在于词向量中
# churchs不存在于词向量中
# wallaces不存在于词向量中
# togetherthe不存在于词向量中
# codys不存在于词向量中
# bacons不存在于词向量中
# fatherson不存在于词向量中
# cb4不存在于词向量中
# badit不存在于词向量中
# lifeit不存在于词向量中
# himthis不存在于词向量中
# sagemiller不存在于词向量中
# vasey不存在于词向量中
# timeand不存在于词向量中
# $1000000不存在于词向量中
# lovethe不存在于词向量中
# goyokin不存在于词向量中
# karens不存在于词向量中
# shin-aes不存在于词向量中
# funthe不存在于词向量中
# filmwhat不存在于词向量中
# latters不存在于词向量中
# tothe不存在于词向量中
# ursulas不存在于词向量中
# realitythe不存在于词向量中
# badbut不存在于词向量中
# joans不存在于词向量中
# bestthe不存在于词向量中
# porters不存在于词向量中
# moviesbut不存在于词向量中
# anothers不存在于词向量中
# greenes不存在于词向量中
# arnolds不存在于词向量中
# dor不存在于词向量中
# isthis不存在于词向量中
# timesi不存在于词向量中
# spoilersi不存在于词向量中
# alberts不存在于词向量中
# doyles不存在于词向量中
# jaffa不存在于词向量中
# cassidys不存在于词向量中
# worsethe不存在于词向量中
# recap:不存在于词向量中
# offi不存在于词向量中
# greendale不存在于词向量中
# todds不存在于词向量中
# indias不存在于词向量中
# caligari不存在于词向量中
# crapthe不存在于词向量中
# rev不存在于词向量中
# yikes不存在于词向量中
# doone不存在于词向量中
# yentl不存在于词向量中
# outi不存在于词向量中
# presque不存在于词向量中
# billys不存在于词向量中
# 10000不存在于词向量中
# bosss不存在于词向量中
# foxxs不存在于词向量中
# rocknroll不存在于词向量中
# robertsons不存在于词向量中
# itim不存在于词向量中
# ruths不存在于词向量中
# booki不存在于词向量中
# sauras不存在于词向量中
# ummm不存在于词向量中
# horrorcomedy不存在于词向量中
# himi不存在于词向量中
# vice-versa不存在于词向量中
# marias不存在于词向量中
# sabrinas不存在于词向量中
# segals不存在于词向量中
# comedythe不存在于词向量中
# filmas不存在于词向量中
# fatherthe不存在于词向量中
# elliotts不存在于词向量中
# roths不存在于词向量中
# nelsons不存在于词向量中
# bronsons不存在于词向量中
# kidmans不存在于词向量中
# onethis不存在于词向量中
# wests不存在于词向量中
# brians不存在于词向量中
# filmone不存在于词向量中
# knowthe不存在于词向量中
# wellbut不存在于词向量中
# warthe不存在于词向量中
# demilles不存在于词向量中
# esthers不存在于词向量中
# screeni不存在于词向量中
# leighs不存在于词向量中
# timesbut不存在于词向量中
# francos不存在于词向量中
# umm不存在于词向量中
# toi不存在于词向量中
# experiencei不存在于词向量中
# againit不存在于词向量中
# colmans不存在于词向量中
# terriblethe不存在于词向量中
# daddys不存在于词向量中
# effectsthe不存在于词向量中
# historythe不存在于词向量中
# withthe不存在于词向量中
# euripides不存在于词向量中
# thingsthe不存在于词向量中
# oneil不存在于词向量中
# columbos不存在于词向量中
# sweetin不存在于词向量中
# allit不存在于词向量中
# dahmers不存在于词向量中
# nablus不存在于词向量中
# cheadles不存在于词向量中
# daviss不存在于词向量中
# daysthe不存在于词向量中
# granddaughters不存在于词向量中
# interestingthe不存在于词向量中
# goodthis不存在于词向量中
# addy不存在于词向量中
# schumachers不存在于词向量中
# moviemy不存在于词向量中
# nwh不存在于词向量中
# happenthe不存在于词向量中
# blithe不存在于词向量中
# 999%不存在于词向量中
# timea不存在于词向量中
# tiffanys不存在于词向量中
# simbas不存在于词向量中
# caesars不存在于词向量中
# robins不存在于词向量中
# tierneys不存在于词向量中
# paltrows不存在于词向量中
# thatbut不存在于词向量中
# $100000不存在于词向量中
# grays不存在于词向量中
# allits不存在于词向量中
# voights不存在于词向量中
# bei不存在于词向量中
# chers不存在于词向量中
# somethingi不存在于词向量中
# mayors不存在于词向量中
# throughi不存在于词向量中
# rafiki不存在于词向量中
# allendes不存在于词向量中
# chinas不存在于词向量中
# orwells不存在于词向量中
# walkin不存在于词向量中
# lius不存在于词向量中
# facethe不存在于词向量中
# menstruation不存在于词向量中
# 2036不存在于词向量中
# anywayi不存在于词向量中
# ohearn不存在于词向量中
# actorsthe不存在于词向量中
# pickfords不存在于词向量中
# cmon!不存在于词向量中
# redgraves不存在于词向量中
# alienator不存在于词向量中
# shantytown不存在于词向量中
# upi不存在于词向量中
# youit不存在于词向量中
# pythons不存在于词向量中
# movieall不存在于词向量中
# timeif不存在于词向量中
# mclaglens不存在于词向量中
# thingthe不存在于词向量中
# pandoras不存在于词向量中
# mankinds不存在于词向量中
# videodvd不存在于词向量中
# itall不存在于词向量中
# himher不存在于词向量中
# armstrongs不存在于词向量中
# gromit不存在于词向量中
# peepers不存在于词向量中
# boyers不存在于词向量中
# actioncomedy不存在于词向量中
# shahs不存在于词向量中
# starsthe不存在于词向量中
# gentileschi不存在于词向量中
# louiss不存在于词向量中
# edisons不存在于词向量中
# ksun不存在于词向量中
# clays不存在于词向量中
# bagman不存在于词向量中
# christies不存在于词向量中
# therere不存在于词向量中
# peggs不存在于词向量中
# brendans不存在于词向量中
# coles不存在于词向量中
# dahls不存在于词向量中
# baldwins不存在于词向量中
# spocks不存在于词向量中
# differentthe不存在于词向量中
# knowi不存在于词向量中
# muertos不存在于词向量中
# sadthe不存在于词向量中
# themthere不存在于词向量中
# itfor不存在于词向量中
# sants不存在于词向量中
# scarlets不存在于词向量中
# dogville不存在于词向量中
# malfatti不存在于词向量中
# lucys不存在于词向量中
# oleary不存在于词向量中
# chens不存在于词向量中
# montanas不存在于词向量中
# garys不存在于词向量中
# inthe不存在于词向量中
# moviedo不存在于词向量中
# fays不存在于词向量中
# oconnors不存在于词向量中
# julians不存在于词向量中
# momentsthe不存在于词向量中
# walshs不存在于词向量中
# bloss不存在于词向量中
# grinchs不存在于词向量中
# coulardeau不存在于词向量中
# gillians不存在于词向量中
# chibas不存在于词向量中
# offthe不存在于词向量中
# barrymores不存在于词向量中
# donethe不存在于词向量中
# timeits不存在于词向量中
# frankensteins不存在于词向量中
# sm不存在于词向量中
# bunuels不存在于词向量中
# eyesthe不存在于词向量中
# matata不存在于词向量中
# crosbys不存在于词向量中
# maetel不存在于词向量中
# genrethe不存在于词向量中
# outthis不存在于词向量中
# cannavale不存在于词向量中
# labours不存在于词向量中
# wasthe不存在于词向量中
# toothis不存在于词向量中
# hamlets不存在于词向量中
# natalis不存在于词向量中
# yaara不存在于词向量中
# canadas不存在于词向量中
# okay!不存在于词向量中
# brotherthe不存在于词向量中
# seans不存在于词向量中
# reids不存在于词向量中
# backthe不存在于词向量中
# ritas不存在于词向量中
# worki不存在于词向量中
# moi不存在于词向量中
# christines不存在于词向量中
# graysons不存在于词向量中
# hima不存在于词向量中
# harveys不存在于词向量中
# draculas不存在于词向量中
# deaththe不存在于词向量中
# aroundthe不存在于词向量中
# banjos不存在于词向量中
# atlantian不存在于词向量中
# wasis不存在于词向量中
# lubitschs不存在于词向量中
# castthe不存在于词向量中
# noltes不存在于词向量中
# prag不存在于词向量中
# tronje不存在于词向量中
# quaids不存在于词向量中
# abouti不存在于词向量中
# familythis不存在于词向量中
# kundry不存在于词向量中
# studi不存在于词向量中
# etci不存在于词向量中
# heinleins不存在于词向量中
# thisbut不存在于词向量中
# masseys不存在于词向量中
# scenesi不存在于词向量中
# zanes不存在于词向量中
# milvertons不存在于词向量中
# rs不存在于词向量中
# thisits不存在于词向量中
# $399不存在于词向量中
# originalthe不存在于词向量中
# himin不存在于词向量中
# edies不存在于词向量中
# 10i不存在于词向量中
# bolkan不存在于词向量中
# mindthe不存在于词向量中
# themin不存在于词向量中
# hitler:不存在于词向量中
# wellif不存在于词向量中
# musici不存在于词向量中
# cf不存在于词向量中
# slovenia不存在于词向量中
# joness不存在于词向量中
# goodand不存在于词向量中
# itwe不存在于词向量中
# paynes不存在于词向量中
# himselfthe不存在于词向量中
# 50000不存在于词向量中
# thatif不存在于词向量中
# drakes不存在于词向量中
# kongs不存在于词向量中
# ini不存在于词向量中
# matarazzo不存在于词向量中
# therethis不存在于词向量中
# believablethe不存在于词向量中
# bogdanovichs不存在于词向量中
# mt不存在于词向量中
# hoppers不存在于词向量中
# rightthe不存在于词向量中
# mackendrick不存在于词向量中
# blakes不存在于词向量中
# clampetts不存在于词向量中
# thatd不存在于词向量中
# 20000不存在于词向量中
# reas不存在于词向量中
# liottas不存在于词向量中
# allthis不存在于词向量中
# kitchens不存在于词向量中
# endingi不存在于词向量中
# soi不存在于词向量中
# yearsthe不存在于词向量中
# genma不存在于词向量中
# grasshopper不存在于词向量中
# longthe不存在于词向量中
# arrondissement不存在于词向量中
# overi不存在于词向量中
# announcers不存在于词向量中
# characterand不存在于词向量中
# threetitle不存在于词向量中
# becks不存在于词向量中
# actorsi不存在于词向量中
# thered不存在于词向量中
# mysterythriller不存在于词向量中
# thisit不存在于词向量中
# livesthe不存在于词向量中
# awfulthe不存在于词向量中
# itselfthe不存在于词向量中
# 185:1不存在于词向量中
# normans不存在于词向量中
# lanzas不存在于词向量中
# fourtitle不存在于词向量中
# raimis不存在于词向量中
# drivas不存在于词向量中
# scrooges不存在于词向量中
# simms不存在于词向量中
# besti不存在于词向量中
# lorens不存在于词向量中
# hannas不存在于词向量中
# macleans不存在于词向量中
# timeit不存在于词向量中
# peckers不存在于词向量中
# jellybean不存在于词向量中
# genies不存在于词向量中
# rg不存在于词向量中
# storylinethe不存在于词向量中
# themselvesthe不存在于词向量中
# funnyand不存在于词向量中
# uhm不存在于词向量中
# untergang不存在于词向量中
# jindabyne不存在于词向量中
# clooneys不存在于词向量中
# onethere不存在于词向量中
# madsens不存在于词向量中
# spanglish不存在于词向量中
# waythis不存在于词向量中
# 00s不存在于词向量中
# larrys不存在于词向量中
# releasedthe不存在于词向量中
# wasthis不存在于词向量中
# gregorys不存在于词向量中
# historys不存在于词向量中
# lawton不存在于词向量中
# niki不存在于词向量中
# anyonethe不存在于词向量中
# periodthe不存在于词向量中
# tyrannus不存在于词向量中
# kirks不存在于词向量中
# helpers不存在于词向量中
# horrorsci-fi不存在于词向量中
# sicas不存在于词向量中
# dannings不存在于词向量中
# schwarzeneggers不存在于词向量中
# rhys-meyers不存在于词向量中
# luque不存在于词向量中
# charactersi不存在于词向量中
# creasys不存在于词向量中
# afis不存在于词向量中
# heartthe不存在于词向量中
# johnny!不存在于词向量中
# afflecks不存在于词向量中
# meso不存在于词向量中
# mamas不存在于词向量中
# againand不存在于词向量中
# throughthe不存在于词向量中
# zeffirellis不存在于词向量中
# aka:不存在于词向量中
# gespenster不存在于词向量中
# shotthe不存在于词向量中
# perú不存在于词向量中
# kopins不存在于词向量中
# ashura不存在于词向量中
# movieeven不存在于词向量中
# lisas不存在于词向量中
# meit不存在于词向量中
# depalmas不存在于词向量中
# geres不存在于词向量中
# weirs不存在于词向量中
# phlox不存在于词向量中
# redline不存在于词向量中
# soso不存在于词向量中
# timesthis不存在于词向量中
# solomons不存在于词向量中
# fiancés不存在于词向量中
# specialthe不存在于词向量中
# houseboat不存在于词向量中
# thereand不存在于词向量中
# grahams不存在于词向量中
# kusturicas不存在于词向量中
# eds不存在于词向量中
# mols不存在于词向量中
# bobbys不存在于词向量中
# kornman不存在于词向量中
# dosent不存在于词向量中
# everthe不存在于词向量中
# stanleys不存在于词向量中
# mcqueens不存在于词向量中
# nortons不存在于词向量中
# filmdont不存在于词向量中
# trex不存在于词向量中
# predictablethe不存在于词向量中
# conaway不存在于词向量中
# noras不存在于词向量中
# paines不存在于词向量中
# lengle不存在于词向量中
# todos不存在于词向量中
# etcand不存在于词向量中
# earththe不存在于词向量中
# jesss不存在于词向量中
# prizzis不存在于词向量中
# donei不存在于词向量中
# basra不存在于词向量中
# vidals不存在于词向量中
# grot不存在于词向量中
# notthis不存在于词向量中
# bouzaglo不存在于词向量中
# wodehouses不存在于词向量中
# themas不存在于词向量中
# ninetitle不存在于词向量中
# deniros不存在于词向量中
# offthis不存在于词向量中
# kitamuras不存在于词向量中
# goshas不存在于词向量中
# musicthe不存在于词向量中
# oooh不存在于词向量中
# :o不存在于词向量中
# klines不存在于词向量中
# endingthe不存在于词向量中
# timebut不存在于词向量中
# chavezs不存在于词向量中
# goodbad不存在于词向量中
# misha不存在于词向量中
# dooleys不存在于词向量中
# directori不存在于词向量中
# ustinovs不存在于词向量中
# wayit不存在于词向量中
# bladerunner不存在于词向量中
# marolla不存在于词向量中
# madei不存在于词向量中
# kapoors不存在于词向量中
# iliad不存在于词向量中
# myrtles不存在于词向量中
# pransky不存在于词向量中
# kolchaks不存在于词向量中
# mole-men不存在于词向量中
# claras不存在于词向量中
# womenthe不存在于词向量中
# elsethe不存在于词向量中
# peoplei不存在于词向量中
# hollys不存在于词向量中
# newbern不存在于词向量中
# sorter不存在于词向量中
# sows不存在于词向量中
# colombo不存在于词向量中
# dir不存在于词向量中
# alvins不存在于词向量中
# awaythe不存在于词向量中
# bakes不存在于词向量中
# detre不存在于词向量中
# moronie不存在于词向量中
# kriemhilds不存在于词向量中
# 1895不存在于词向量中
# poppa不存在于词向量中
# atlantis:不存在于词向量中
# filmsbut不存在于词向量中
# mcdiarmid不存在于词向量中
# yearthe不存在于词向量中
# holmess不存在于词向量中
# insteadthe不存在于词向量中
# beban不存在于词向量中
# exterminators不存在于词向量中
# characteri不存在于词向量中
# sleepthe不存在于词向量中
# goldblums不存在于词向量中
# jobthe不存在于词向量中
# ex-mrs不存在于词向量中
# timeas不存在于词向量中
# hilariousi不存在于词向量中
# giovannas不存在于词向量中
# approx不存在于词向量中
# ow不存在于词向量中
# fly-fishing不存在于词向量中
# bavas不存在于词向量中
# gordone不存在于词向量中
# elsei不存在于词向量中
# filmfirst不存在于词向量中
# amitabhs不存在于词向量中
# denzels不存在于词向量中
# costners不存在于词向量中
# themso不存在于词向量中
# allin不存在于词向量中
# ownthe不存在于词向量中
# unicorn不存在于词向量中
# singletons不存在于词向量中
# hermans不存在于词向量中
# sothe不存在于词向量中
# moviefor不存在于词向量中
# moneythe不存在于词向量中
# dandys不存在于词向量中
# hazlehurst不存在于词向量中
# 05不存在于词向量中
# checkpoints不存在于词向量中
# **12不存在于词向量中
# filmnow不存在于词向量中
# sheridans不存在于词向量中
# iteven不存在于词向量中
# paxtons不存在于词向量中
# sammos不存在于词向量中
# nguyen不存在于词向量中
# wardh不存在于词向量中
# otheri不存在于词向量中
# b:tas不存在于词向量中
# waltons不存在于词向量中
# starlift不存在于词向量中
# sascha不存在于词向量中
# stettner不存在于词向量中
# harriss不存在于词向量中
# situationthe不存在于词向量中
# boormans不存在于词向量中
# hinduism不存在于词向量中
# homicide:不存在于词向量中
# dayi不存在于词向量中
# himselfi不存在于词向量中
# bradburys不存在于词向量中
# salaam-e-ishq不存在于词向量中
# themif不存在于词向量中
# 247不存在于词向量中
# wonderfulthe不存在于词向量中
# paulas不存在于词向量中
# berkeleys不存在于词向量中
# alexanders不存在于词向量中
# pyewacket不存在于词向量中
# feinstones不存在于词向量中
# stevensons不存在于词向量中
# chongs不存在于词向量中
# marleen不存在于词向量中
# hadleys不存在于词向量中
# hightower不存在于词向量中
# evas不存在于词向量中
# kikis不存在于词向量中
# ieks不存在于词向量中
# itnow不存在于词向量中
# lenas不存在于词向量中
# mockingbird不存在于词向量中
# coolio不存在于词向量中
# shinobi不存在于词向量中
# locataire不存在于词向量中
# contra不存在于词向量中
# itwell不存在于词向量中
# clarkes不存在于词向量中
# mcenroe不存在于词向量中
# $250000不存在于词向量中
# onebut不存在于词向量中
# thisand不存在于词向量中
# youthis不存在于词向量中
# ellens不存在于词向量中
# wus不存在于词向量中
# sandras不存在于词向量中
# mums不存在于词向量中
# spoorloos不存在于词向量中
# watchand不存在于词向量中
# hungs不存在于词向量中
# ndour不存在于词向量中
# faubourg不存在于词向量中
# mccoys不存在于词向量中
# mid-60s不存在于词向量中
# elizabeths不存在于词向量中
# trainor不存在于词向量中
# himbut不存在于词向量中
# flickthe不存在于词向量中
# cruellas不存在于词向量中
# mildreds不存在于词向量中
# askeys不存在于词向量中
# springers不存在于词向量中
# mustnt不存在于词向量中
# ridiculousthe不存在于词向量中
# solvang不存在于词向量中
# redfords不存在于词向量中
# minnellis不存在于词向量中
# togetheri不存在于词向量中
# 2s不存在于词向量中
# moviesand不存在于词向量中
# meow不存在于词向量中
# sabretooths不存在于词向量中
# dabo不存在于词向量中
# mine!不存在于词向量中
# seeing!不存在于词向量中
# haywards不存在于词向量中
# coronets不存在于词向量中
# classicthe不存在于词向量中
# crimethe不存在于词向量中
# rouges不存在于词向量中
# homelessness不存在于词向量中
# appolonia不存在于词向量中
# nextthe不存在于词向量中
# excellentthe不存在于词向量中
# neer-do-well不存在于词向量中
# cunninghams不存在于词向量中
# $50000不存在于词向量中
# chomskys不存在于词向量中
# whythe不存在于词向量中
# nightthe不存在于词向量中
# cantillana不存在于词向量中
# wayand不存在于词向量中
# dystrophy不存在于词向量中
# herren不存在于词向量中
# tur不存在于词向量中
# pepi不存在于词向量中
# coursethe不存在于词向量中
# shant不存在于词向量中
# reali不存在于词向量中
# downthe不存在于词向量中
# directorco-writer不存在于词向量中
# tulipe不存在于词向量中
# incomprehensibility不存在于词向量中
# claires不存在于词向量中
# onand不存在于词向量中
# kunderas不存在于词向量中
# laterthe不存在于词向量中
# finneys不存在于词向量中
# thrillerhorror不存在于词向量中
# ryker不存在于词向量中
# olan不存在于词向量中
# numar不存在于词向量中
# masterpiecethe不存在于词向量中
# barbaras不存在于词向量中
# entertainingthe不存在于词向量中
# zhu不存在于词向量中
# wastrel不存在于词向量中
# chalo不存在于词向量中
# youif不存在于词向量中
# lewtons不存在于词向量中
# comstock不存在于词向量中
# outit不存在于词向量中
# ravine不存在于词向量中
# thaws不存在于词向量中
# garber不存在于词向量中
# shos不存在于词向量中
# ouch不存在于词向量中
# onemy不存在于词向量中
# doi不存在于词向量中
# haenel不存在于词向量中
# linklaters不存在于词向量中
# willys不存在于词向量中
# gades不存在于词向量中
# movienow不存在于词向量中
# airlift不存在于词向量中
# sweid不存在于词向量中
# annoyingthe不存在于词向量中
# 235:1不存在于词向量中
# hartnetts不存在于词向量中
# colonels不存在于词向量中
# kabei不存在于词向量中
# spartacus不存在于词向量中
# corleones不存在于词向量中
# nivens不存在于词向量中
# atthe不存在于词向量中
# potters不存在于词向量中
# anthonys不存在于词向量中
# motherthe不存在于词向量中
# dibiases不存在于词向量中
# ninotchka不存在于词向量中
# todaythe不存在于词向量中
# carons不存在于词向量中
# tarkovskys不存在于词向量中
# germanys不存在于词向量中
# btas不存在于词向量中
# moviefirst不存在于词向量中
# ghandi不存在于词向量中
# performancethe不存在于词向量中
# nuyoricans不存在于词向量中
# movieas不存在于词向量中
# pascow不存在于词向量中
# lateri不存在于词向量中
# mabuse不存在于词向量中
# malones不存在于词向量中
# abbys不存在于词向量中
# alta不存在于词向量中
# rostov不存在于词向量中
# travail不存在于词向量中
# itthey不存在于词向量中
# arethe不存在于词向量中
# mathieus不存在于词向量中
# pharaohs不存在于词向量中
# genova不存在于词向量中
# herethis不存在于词向量中
# thatand不存在于词向量中
# syberbergs不存在于词向量中
# usthe不存在于词向量中
# kordas不存在于词向量中
# elmos不存在于词向量中
# greati不存在于词向量中
# daves不存在于词向量中
# tx不存在于词向量中
# coxs不存在于词向量中
# minutesi不存在于词向量中
# gores不存在于词向量中
# davidtz不存在于词向量中
# overthe不存在于词向量中
# 06不存在于词向量中
# wymer不存在于词向量中
# caspers不存在于词向量中
# jouissance不存在于词向量中
# haims不存在于词向量中
# chenoweth不存在于词向量中
# beckinsales不存在于词向量中
# fitzgeralds不存在于词向量中
# comedyi不存在于词向量中
# freds不存在于词向量中
# ligabue不存在于词向量中
# laputa:不存在于词向量中
# see!!!不存在于词向量中
# sorvinos不存在于词向量中
# mcandrew不存在于词向量中
# courtland不存在于词向量中
# stylethe不存在于词向量中
# jariwala不存在于词向量中
# arnies不存在于词向量中
# schneebaums不存在于词向量中
# tora不存在于词向量中
# pabsts不存在于词向量中
# violencethe不存在于词向量中
# shinae不存在于词向量中
# 1the不存在于词向量中
# schneiders不存在于词向量中
# narsimha不存在于词向量中
# goodit不存在于词向量中
# gubra不存在于词向量中
# carnality不存在于词向量中
# remoteness不存在于词向量中
# munshi不存在于词向量中
# upthis不存在于词向量中
# pulps不存在于词向量中
# careerthe不存在于词向量中
# dorie不存在于词向量中
# heyerdahl不存在于词向量中
# lv1不存在于词向量中
# magruder不存在于词向量中
# agethe不存在于词向量中
# thatits不存在于词向量中
# horrorgore不存在于词向量中
# stuffthe不存在于词向量中
# remer不存在于词向量中
# hagars不存在于词向量中
# goodin不存在于词向量中
# nowthe不存在于词向量中
# lacan不存在于词向量中
# stupidthe不存在于词向量中
# sheedys不存在于词向量中
# zavet不存在于词向量中
# salmans不存在于词向量中
# antitrust不存在于词向量中
# cronenbergs不存在于词向量中
# soweto不存在于词向量中
# kusama不存在于词向量中
# ofthis不存在于词向量中
# canyons不存在于词向量中
# cloudkicker不存在于词向量中
# chahines不存在于词向量中
# mastersons不存在于词向量中
# steppers不存在于词向量中
# miryang不存在于词向量中
# alekos不存在于词向量中
# performancesthe不存在于词向量中
# watsons不存在于词向量中
# filmim不存在于词向量中
# shelleys不存在于词向量中
# gothe不存在于词向量中
# trents不存在于词向量中
# marions不存在于词向量中
# pieuvres不存在于词向量中
# zomcon不存在于词向量中
# arzenta不存在于词向量中
# agothe不存在于词向量中
# scolas不存在于词向量中
# casti不存在于词向量中
# pons不存在于词向量中
# himmelen不存在于词向量中
# societythe不存在于词向量中
# garbagethe不存在于词向量中
# imamuras不存在于词向量中
# sensethe不存在于词向量中
# charactersit不存在于词向量中
# fitzs不存在于词向量中
# horriblethe不存在于词向量中
# bromell不存在于词向量中
# dellorco不存在于词向量中
# andretti不存在于词向量中
# naissance不存在于词向量中
# worldin不存在于词向量中
# paedophilia不存在于词向量中
# tchaikovskys不存在于词向量中
# gurnemanz不存在于词向量中
# directorthe不存在于词向量中
# brideless不存在于词向量中
# guythe不存在于词向量中
# beerys不存在于词向量中
# 237不存在于词向量中
# thoughthis不存在于词向量中
# businessthe不存在于词向量中
# wolfs不存在于词向量中
# alls不存在于词向量中
# decors不存在于词向量中
# mencias不存在于词向量中
# sabus不存在于词向量中
# daysthis不存在于词向量中
# changs不存在于词向量中
# jennas不存在于词向量中
# itmy不存在于词向量中
# subor不存在于词向量中
# bibles不存在于词向量中
# warthog不存在于词向量中
# 70s80s不存在于词向量中
# windscreen不存在于词向量中
# cinemathis不存在于词向量中
# cimarron不存在于词向量中
# mexicos不存在于词向量中
# andwell不存在于词向量中
# bedi不存在于词向量中
# shatners不存在于词向量中
# movieon不存在于词向量中
# stiflers不存在于词向量中
# everi不存在于词向量中
# gft不存在于词向量中
# trautman不存在于词向量中
# faso不存在于词向量中
# shits不存在于词向量中
# unfaithfulness不存在于词向量中
# iswhat不存在于词向量中
# tans不存在于词向量中
# 60searly不存在于词向量中
# diplomacy不存在于词向量中
# missing!不存在于词向量中
# fontaines不存在于词向量中
# ismy不存在于词向量中
# vampires:不存在于词向量中
# hak不存在于词向量中
# slaters不存在于词向量中
# gasp!不存在于词向量中
# :=8p不存在于词向量中
# $25000不存在于词向量中
# altaira不存在于词向量中
# linethe不存在于词向量中
# lexs不存在于词向量中
# dilly不存在于词向量中
# danas不存在于词向量中
# saras不存在于词向量中
# levinsons不存在于词向量中
# goodoverall不存在于词向量中
# andrés不存在于词向量中
# jennys不存在于词向量中
# surprisethe不存在于词向量中
# isits不存在于词向量中
# choco不存在于词向量中
# itive不存在于词向量中
# castorini不存在于词向量中
# yousef不存在于词向量中
# levants不存在于词向量中
# apposite不存在于词向量中
# cornillac不存在于词向量中
# youin不存在于词向量中
# patheticthe不存在于词向量中
# tonalities不存在于词向量中
# lantana不存在于词向量中
# boringthe不存在于词向量中
# deniss不存在于词向量中
# holroyd不存在于词向量中
# mehbooba不存在于词向量中
# florianes不存在于词向量中
# inand不存在于词向量中
# dykes不存在于词向量中
# uh-huh不存在于词向量中
# anythingi不存在于词向量中
# miraglias不存在于词向量中
# **possible不存在于词向量中
# urbaniak不存在于词向量中
# huggaland不存在于词向量中
# martindale不存在于词向量中
# deads不存在于词向量中
# bethis不存在于词向量中
# subjectthe不存在于词向量中
# murrays不存在于词向量中
# watchif不存在于词向量中
# laughthe不存在于词向量中
# burts不存在于词向量中
# storyone不存在于词向量中
# chabrols不存在于词向量中
# infinitum不存在于词向量中
# dassins不存在于词向量中
# 02不存在于词向量中
# belaney不存在于词向量中
# tybalt不存在于词向量中
# volckmans不存在于词向量中
# vics不存在于词向量中
# wrestlemanias不存在于词向量中
# grandmas不存在于词向量中
# filmsits不存在于词向量中
# gypos不存在于词向量中
# midlers不存在于词向量中
# ryecart不存在于词向量中
# tremayne不存在于词向量中
# nr不存在于词向量中
# herthis不存在于词向量中
# publications不存在于词向量中
# waysthe不存在于词向量中
# scenethe不存在于词向量中
# platos不存在于词向量中
# soloist不存在于词向量中
# greystoke不存在于词向量中
# peopleif不存在于词向量中
# farnsworths不存在于词向量中
# iswas不存在于词向量中
# halprin不存在于词向量中
# celies不存在于词向量中
# momentsi不存在于词向量中
# crains不存在于词向量中
# quantrill不存在于词向量中
# palances不存在于词向量中
# choule不存在于词向量中
# waterdance不存在于词向量中
# bradys不存在于词向量中
# wolverines不存在于词向量中
# crowd-pleaser不存在于词向量中
# film1不存在于词向量中
# forthe不存在于词向量中
# hitoto不存在于词向量中
# bjorlin不存在于词向量中
# themand不存在于词向量中
# firestarter不存在于词向量中
# peoplethis不存在于词向量中
# almodovars不存在于词向量中
# toros不存在于词向量中
# boz不存在于词向量中
# hallgren不存在于词向量中
# frwl不存在于词向量中
# gabel不存在于词向量中
# two-parter不存在于词向量中
# saint-denis不存在于词向量中
# rangi不存在于词向量中
# prairies不存在于词向量中
# roedel不存在于词向量中
# julias不存在于词向量中
# notebooks不存在于词向量中
# barmans不存在于词向量中
# thisa不存在于词向量中
# filmwhich不存在于词向量中
# placei不存在于词向量中
# wellingtons不存在于词向量中
# sydows不存在于词向量中
# 5ive不存在于词向量中
# caracas不存在于词向量中
# lovin不存在于词向量中
# uks不存在于词向量中
# buttgereits不存在于词向量中
# panaghoy不存在于词向量中
# seethe不存在于词向量中
# hereits不存在于词向量中
# backi不存在于词向量中
# hillyers不存在于词向量中
# itlike不存在于词向量中
# unsinkable不存在于词向量中
# momentthe不存在于词向量中
# demmes不存在于词向量中
# pyms不存在于词向量中
# lohans不存在于词向量中
# cinemagic不存在于词向量中
# shemps不存在于词向量中
# namethe不存在于词向量中
# funnyit不存在于词向量中
# interestingthis不存在于词向量中
# betterthis不存在于词向量中
# momentsbut不存在于词向量中
# yetthe不存在于词向量中
# fulbright不存在于词向量中
# didnt!不存在于词向量中
# centurythe不存在于词向量中
# finally!不存在于词向量中
# likei不存在于词向量中
# deadthe不存在于词向量中
# $750不存在于词向量中
# cristinas不存在于词向量中
# aphrodite不存在于词向量中
# mirage不存在于词向量中
# 1983s不存在于词向量中
# twothe不存在于词向量中
# entertainmentthe不存在于词向量中
# fini不存在于词向量中
# youand不存在于词向量中
# laroche不存在于词向量中
# cameramans不存在于词向量中
# goldsmiths不存在于词向量中
# charnier不存在于词向量中
# laughsthe不存在于词向量中
# pallbearer不存在于词向量中
# upbut不存在于词向量中
# tiempo不存在于词向量中
# frownland不存在于词向量中
# yvelines不存在于词向量中
# toshi不存在于词向量中
# coppolas不存在于词向量中
# neenan不存在于词向量中
# carusos不存在于词向量中
# etcthis不存在于词向量中
# timberlakes不存在于词向量中
# effectsi不存在于词向量中
# unforgiven不存在于词向量中
# lloyds不存在于词向量中
# takechi不存在于词向量中
# ecclestone不存在于词向量中
# wellits不存在于词向量中
# along!不存在于词向量中
# noams不存在于词向量中
# basingers不存在于词向量中
# fuquas不存在于词向量中
# mohawk不存在于词向量中
# naudets不存在于词向量中
# endit不存在于词向量中
# watchingthe不存在于词向量中
# spagnolo不存在于词向量中
# kramers不存在于词向量中
# tets不存在于词向量中
# sallys不存在于词向量中
# 60000不存在于词向量中
# vadis不存在于词向量中
# verger不存在于词向量中
# pyuns不存在于词向量中
# materialthe不存在于词向量中
# lovethis不存在于词向量中
# thunderchild不存在于词向量中
# edmunds不存在于词向量中
# ardelean不存在于词向量中
# shit不存在于词向量中
# aboutand不存在于词向量中
# madagascar不存在于词向量中
# wolfes不存在于词向量中
# morei不存在于词向量中
# brashears不存在于词向量中
# oneills不存在于词向量中
# denard不存在于词向量中
# filmall不存在于词向量中
# lube不存在于词向量中
# badthis不存在于词向量中
# moviewhat不存在于词向量中
# mathesons不存在于词向量中
# funnythis不存在于词向量中
# outthere不存在于词向量中
# farscape不存在于词向量中
# fawcetts不存在于词向量中
# seenit不存在于词向量中
# curtiss不存在于词向量中
# junge不存在于词向量中
# rashid不存在于词向量中
# itat不存在于词向量中
# filmsit不存在于词向量中
# vera-ellens不存在于词向量中
# meas不存在于词向量中
# hiltz不存在于词向量中
# salems不存在于词向量中
# holcomb不存在于词向量中
# cybersix不存在于词向量中
# melvilles不存在于词向量中
# yearsi不存在于词向量中
# rounders不存在于词向量中
# ginos不存在于词向量中
# silverware不存在于词向量中
# shiner不存在于词向量中
# sherrys不存在于词向量中
# no2不存在于词向量中
# 4-3不存在于词向量中
# actionthe不存在于词向量中
# downi不存在于词向量中
# shanao不存在于词向量中
# machi不存在于词向量中
# gas!不存在于词向量中
# wongs不存在于词向量中
# pseudoscience不存在于词向量中
# wrongthis不存在于词向量中
# joycelyn不存在于词向量中
# gato不存在于词向量中
# lady!不存在于词向量中
# anistons不存在于词向量中
# earlys不存在于词向量中
# thembut不存在于词向量中
# debenning不存在于词向量中
# yearsbut不存在于词向量中
# anotherthe不存在于词向量中
# thatch不存在于词向量中
# donnisons不存在于词向量中
# timesin不存在于词向量中
# itwhen不存在于词向量中
# larn不存在于词向量中
# actingand不存在于词向量中
# itthats不存在于词向量中
# yall不存在于词向量中
# necroborgs不存在于词向量中
# solent不存在于词向量中
# lage不存在于词向量中
# workit不存在于词向量中
# mistakei不存在于词向量中
# editingthe不存在于词向量中
# sukowa不存在于词向量中
# beit不存在于词向量中
# rataud不存在于词向量中
# awayi不存在于词向量中
# coalwood不存在于词向量中
# moviemost不存在于词向量中
# zombification不存在于词向量中
# 4510不存在于词向量中
# chandon不存在于词向量中
# detat不存在于词向量中
# bromfield不存在于词向量中
# moviewhen不存在于词向量中
# swifts不存在于词向量中
# elviss不存在于词向量中
# barsi不存在于词向量中
# italys不存在于词向量中
# artisans不存在于词向量中
# againthis不存在于词向量中
# bachs不存在于词向量中
# ha-ha不存在于词向量中
# peopleand不存在于词向量中
# actorthe不存在于词向量中
# lifeand不存在于词向量中
# cq不存在于词向量中
# stupidi不存在于词向量中
# arkins不存在于词向量中
# blairs不存在于词向量中
# bestworst不存在于词向量中
# hornbys不存在于词向量中
# storiesthe不存在于词向量中
# badand不存在于词向量中
# schwartzmans不存在于词向量中
# filmoverall不存在于词向量中
# marner不存在于词向量中
# phibes不存在于词向量中
# cama不存在于词向量中
# wwes不存在于词向量中
# fluegel不存在于词向量中
# itvery不存在于词向量中
# losti不存在于词向量中
# chandlers不存在于词向量中
# bennetts不存在于词向量中
# allbut不存在于词向量中
# cathryn不存在于词向量中
# berkowitzs不存在于词向量中
# stroh不存在于词向量中
# shepards不存在于词向量中
# shirleys不存在于词向量中
# ideathe不存在于词向量中
# exhibitions不存在于词向量中
# poorthe不存在于词向量中
# naught不存在于词向量中
# ariels不存在于词向量中
# moes不存在于词向量中
# burkina不存在于词向量中
# trampa不存在于词向量中
# gerards不存在于词向量中
# therell不存在于词向量中
# poor!不存在于词向量中
# alland不存在于词向量中
# moneyi不存在于词向量中
# understandthe不存在于词向量中
# anew不存在于词向量中
# historyi不存在于词向量中
# rambos不存在于词向量中
# sincethe不存在于词向量中
# ratsos不存在于词向量中
# redrum不存在于词向量中
# wauters不存在于词向量中
# zapatti不存在于词向量中
# gussie不存在于词向量中
# kaun不存在于词向量中
# d-war不存在于词向量中
# productionthe不存在于词向量中
# versioni不存在于词向量中
# waterworld不存在于词向量中
# korsmo不存在于词向量中
# marshalls不存在于词向量中
# scorpione不存在于词向量中
# wurb不存在于词向量中
# lommels不存在于词向量中
# matteis不存在于词向量中
# chirila不存在于词向量中
# lawrences不存在于词向量中
# rookies不存在于词向量中
# cragg不存在于词向量中
# cut!不存在于词向量中
# kinnears不存在于词向量中
# 30000不存在于词向量中
# themall不存在于词向量中
# foxworth不存在于词向量中
# rightthis不存在于词向量中
# gentlemans不存在于词向量中
# audiards不存在于词向量中
# ringside不存在于词向量中
# sub-zero不存在于词向量中
# huh!不存在于词向量中
# vaughns不存在于词向量中
# monarchs不存在于词向量中
# late-60s不存在于词向量中
# dvdi不存在于词向量中
# hbos不存在于词向量中
# aymeric不存在于词向量中
# luján不存在于词向量中
# itselfthis不存在于词向量中
# flicki不存在于词向量中
# chestnuts不存在于词向量中
# `queen不存在于词向量中
# lous不存在于词向量中
# cest不存在于词向量中
# thema不存在于词向量中
# dietrichs不存在于词向量中
# milligans不存在于词向量中
# bueller不存在于词向量中
# knef不存在于词向量中
# nowthis不存在于词向量中
# fallwell不存在于词向量中
# jasons不存在于词向量中
# stolz不存在于词向量中
# turners不存在于词向量中
# barjatyas不存在于词向量中
# superstardom不存在于词向量中
# thurmans不存在于词向量中
# isit不存在于词向量中
# bridgets不存在于词向量中
# thismovie不存在于词向量中
# moviesif不存在于词向量中
# ahista不存在于词向量中
# camerathe不存在于词向量中
# stans不存在于词向量中
# trumans不存在于词向量中
# wasit不存在于词向量中
# interestingand不存在于词向量中
# ramallo不存在于词向量中
# dibley不存在于词向量中
# thuy不存在于词向量中
# hyser不存在于词向量中
# witherspoons不存在于词向量中
# otooles不存在于词向量中
# eustaches不存在于词向量中
# bauraki不存在于词向量中
# yore不存在于词向量中
# alonethe不存在于词向量中
# write-off不存在于词向量中
# loulou不存在于词向量中
# nebula不存在于词向量中
# watership不存在于词向量中
# hauntings不存在于词向量中
# lams不存在于词向量中
# cosimo不存在于词向量中
# climaxthis不存在于词向量中
# *may不存在于词向量中
# facilitator不存在于词向量中
# victoires不存在于词向量中
# hypercube不存在于词向量中
# itone不存在于词向量中
# pvt不存在于词向量中
# livin不存在于词向量中
# timetable不存在于词向量中
# dillons不存在于词向量中
# dangerfields不存在于词向量中
# nixons不存在于词向量中
# bookthe不存在于词向量中
# eitherits不存在于词向量中
# irans不存在于词向量中
# cuoco不存在于词向量中
# undecipherable不存在于词向量中
# uranium不存在于词向量中
# anodyne不存在于词向量中
# titanics不存在于词向量中
# filmthat不存在于词向量中
# filmby不存在于词向量中
# brisbane不存在于词向量中
# sergius不存在于词向量中
# juliana不存在于词向量中
# genn不存在于词向量中
# dkd不存在于词向量中
# rebar不存在于词向量中
# akshays不存在于词向量中
# ermine不存在于词向量中
# cheang不存在于词向量中
# gainey不存在于词向量中
# zuckerman不存在于词向量中
# pias不存在于词向量中
# jakub不存在于词向量中
# hutson不存在于词向量中
# meds不存在于词向量中
# richardsons不存在于词向量中
# himherself不存在于词向量中
# nolans不存在于词向量中
# raina不存在于词向量中
# joshs不存在于词向量中
# torturei不存在于词向量中
# didt不存在于词向量中
# tutors不存在于词向量中
# mistakethe不存在于词向量中
# carradines不存在于词向量中
# meif不存在于词向量中
# ulees不存在于词向量中
# launius不存在于词向量中
# whoopee不存在于词向量中
# hupperts不存在于词向量中
# jesters不存在于词向量中
# antonella不存在于词向量中
# s2t不存在于词向量中
# migraines不存在于词向量中
# notif不存在于词向量中
# penry-jones不存在于词向量中
# masons不存在于词向量中
# doers不存在于词向量中
# byrons不存在于词向量中
# hawns不存在于词向量中
# digicorps不存在于词向量中
# darc不存在于词向量中
# filmto不存在于词向量中
# roxbury不存在于词向量中
# mid-30s不存在于词向量中
# upand不存在于词向量中
# laudenbach不存在于词向量中
# yolande不存在于词向量中
# rainbeaux不存在于词向量中
# itof不存在于词向量中
# deannas不存在于词向量中
# siv不存在于词向量中
# casei不存在于词向量中
# kelada不存在于词向量中
# inhe不存在于词向量中
# starck不存在于词向量中
# lifebut不存在于词向量中
# cuarón不存在于词向量中
# opinioni不存在于词向量中
# 1-2-3不存在于词向量中
# mcnicol不存在于词向量中
# thatso不存在于词向量中
# sadies不存在于词向量中
# deth不存在于词向量中
# poms不存在于词向量中
# dramathe不存在于词向量中
# lessthe不存在于词向量中
# videothe不存在于词向量中
# piedras不存在于词向量中
# collettes不存在于词向量中
# mommys不存在于词向量中
# bernsens不存在于词向量中
# chancethe不存在于词向量中
# rothschild不存在于词向量中
# pasadena不存在于词向量中
# frankie-boy不存在于词向量中
# theni不存在于词向量中
# jesuss不存在于词向量中
# filmoh不存在于词向量中
# klaws不存在于词向量中
# rodneys不存在于词向量中
# flux不存在于词向量中
# cassavettess不存在于词向量中
# slugs:不存在于词向量中
# milford不存在于词向量中
# periodi不存在于词向量中
# margarete不存在于词向量中
# muchit不存在于词向量中
# timedirector不存在于词向量中
# playoffs不存在于词向量中
# thesethe不存在于词向量中
# malamud不存在于词向量中
# who-dunnit不存在于词向量中
# klute不存在于词向量中
# wrights不存在于词向量中
# bannings不存在于词向量中
# ploti不存在于词向量中
# hateable不存在于词向量中
# tippi不存在于词向量中
# vidors不存在于词向量中
# rubys不存在于词向量中
# enoughthe不存在于词向量中
# glenrowan不存在于词向量中
# buddys不存在于词向量中
# amis不存在于词向量中
# rozs不存在于词向量中
# tysons不存在于词向量中
# heorot不存在于词向量中
# bregana不存在于词向量中
# 1894不存在于词向量中
# fani不存在于词向量中
# 4-bad不存在于词向量中
# wellyou不存在于词向量中
# rc不存在于词向量中
# movieshe不存在于词向量中
# burgundians不存在于词向量中
# merediths不存在于词向量中
# asimovs不存在于词向量中
# itwith不存在于词向量中
# barbarella不存在于词向量中
# !!!!!!!!不存在于词向量中
# site!不存在于词向量中
# amazingand不存在于词向量中
# itnot不存在于词向量中
# carrys不存在于词向量中
# hickey不存在于词向量中
# realismthe不存在于词向量中
# tasuiev不存在于词向量中
# forrests不存在于词向量中
# donofrio不存在于词向量中
# moreira不存在于词向量中
# gadar不存在于词向量中
# emigrant不存在于词向量中
# thatthere不存在于词向量中
# roebuck不存在于词向量中
# bambis不存在于词向量中
# gauris不存在于词向量中
# housethe不存在于词向量中
# coixet不存在于词向量中
# gabriels不存在于词向量中
# seriouslythe不存在于词向量中
# akhras不存在于词向量中
# mensonges不存在于词向量中
# narcolepsy不存在于词向量中
# insp不存在于词向量中
# bilious不存在于词向量中
# bullhorn不存在于词向量中
# towelhead不存在于词向量中
# saboteur不存在于词向量中
# dafoes不存在于词向量中
# directionthe不存在于词向量中
# narasimha不存在于词向量中
# tentitle不存在于词向量中
# mauricio不存在于词向量中
# englebert不存在于词向量中
# raffin不存在于词向量中
# nadji不存在于词向量中
# mahers不存在于词向量中
# moviewith不存在于词向量中
# citythe不存在于词向量中
# newell不存在于词向量中
# catherines不存在于词向量中
# facei不存在于词向量中
# directioni不存在于词向量中
# oaters不存在于词向量中
# hereafter不存在于词向量中
# anotherthis不存在于词向量中
# huntingdon不存在于词向量中
# eikenberry不存在于词向量中
# dietrichson不存在于词向量中
# aroundi不存在于词向量中
# pavarottis不存在于词向量中
# brendon不存在于词向量中
# alberta不存在于词向量中
# spiers不存在于词向量中
# actingthis不存在于词向量中
# sin-eater不存在于词向量中
# malthe不存在于词向量中
# katsus不存在于词向量中
# kidsi不存在于词向量中
# tvthe不存在于词向量中
# foleys不存在于词向量中
# kagan不存在于词向量中
# yeari不存在于词向量中
# rookers不存在于词向量中
# beaute不存在于词向量中
# ge999不存在于词向量中
# watchtower不存在于词向量中
# floyds不存在于词向量中
# worsethis不存在于词向量中
# suo不存在于词向量中
# newcombes不存在于词向量中
# hereit不存在于词向量中
# etcit不存在于词向量中
# havethe不存在于词向量中
# dornwinkle不存在于词向量中
# andies不存在于词向量中
# greatand不存在于词向量中
# kolchak:不存在于词向量中
# cassies不存在于词向量中
# tereza不存在于词向量中
# darkheart不存在于词向量中
# onesthe不存在于词向量中
# noland不存在于词向量中
# boen不存在于词向量中
# tftc不存在于词向量中
# moroder不存在于词向量中
# centurys不存在于词向量中
# spradling不存在于词向量中
# amenabars不存在于词向量中
# holms不存在于词向量中
# gulfax不存在于词向量中
# nazgul不存在于词向量中
# prez不存在于词向量中
# absurdness不存在于词向量中
# beethovens不存在于词向量中
# okeeffe不存在于词向量中
# gaillardia不存在于词向量中
# danis不存在于词向量中
# ofi不存在于词向量中
# summersisle不存在于词向量中
# fp1不存在于词向量中
# beforethis不存在于词向量中
# hipness不存在于词向量中
# ginas不存在于词向量中
# natch不存在于词向量中
# tourneurs不存在于词向量中
# producerdirector不存在于词向量中
# schaffer不存在于词向量中
# så不存在于词向量中
# himso不存在于词向量中
# monteith不存在于词向量中
# talentthe不存在于词向量中
# brilliantthe不存在于词向量中
# rolethis不存在于词向量中
# shekhars不存在于词向量中
# durantes不存在于词向量中
# phoenixs不存在于词向量中
# onit不存在于词向量中
# iturbis不存在于词向量中
# consummated不存在于词向量中
# 1s不存在于词向量中
# thrush不存在于词向量中
# bucktown不存在于词向量中
# tel-aviv不存在于词向量中
# alexandres不存在于词向量中
# earlierthe不存在于词向量中
# levene不存在于词向量中
# sculptures不存在于词向量中
# pazus不存在于词向量中
# wendts不存在于词向量中
# wargames:不存在于词向量中
# othellos不存在于词向量中
# 713不存在于词向量中
# linderby不存在于词向量中
# radiofreccia不存在于词向量中
# friendless不存在于词向量中
# matterthe不存在于词向量中
# aswell不存在于词向量中
# repairman不存在于词向量中
# steeles不存在于词向量中
# ambassadors不存在于词向量中
# geisel不存在于词向量中
# pryors不存在于词向量中
# nathans不存在于词向量中
# somethingthis不存在于词向量中
# habitats不存在于词向量中
# mrlincoln不存在于词向量中
# hensons不存在于词向量中
# fois不存在于词向量中
# townsends不存在于词向量中
# justins不存在于词向量中
# grangers不存在于词向量中
# enemys不存在于词向量中
# werewolfs不存在于词向量中
# storyfor不存在于词向量中
# velankar不存在于词向量中
# beetlejuice不存在于词向量中
# herethere不存在于词向量中
# perspectivethe不存在于词向量中
# fidos不存在于词向量中
# williamss不存在于词向量中
# tgif不存在于词向量中
# interestthe不存在于词向量中
# shae不存在于词向量中
# amandas不存在于词向量中
# scenei不存在于词向量中
# successthe不存在于词向量中
# capras不存在于词向量中
# crandall不存在于词向量中
# ak-47不存在于词向量中
# kennicut不存在于词向量中
# filmvery不存在于词向量中
# thatafter不存在于词向量中
# acs不存在于词向量中
# kandice不存在于词向量中
# timesand不存在于词向量中
# langlaise不存在于词向量中
# withi不存在于词向量中
# kattans不存在于词向量中
# eg:不存在于词向量中
# seenthis不存在于词向量中
# iswell不存在于词向量中
# bolero不存在于词向量中
# thingthis不存在于词向量中
# trombone不存在于词向量中
# joyces不存在于词向量中
# bluths不存在于词向量中
# audiencei不存在于词向量中
# welchs不存在于词向量中
# somethingthe不存在于词向量中
# everythingthe不存在于词向量中
# 1010!不存在于词向量中
# trumpeter不存在于词向量中
# catalan不存在于词向量中
# randle不存在于词向量中
# delias不存在于词向量中
# raimy不存在于词向量中
# hadleyville不存在于词向量中
# personi不存在于词向量中
# scoops不存在于词向量中
# itwho不存在于词向量中
# musicthis不存在于词向量中
# chewie不存在于词向量中
# gr不存在于词向量中
# crouses不存在于词向量中
# moviehowever不存在于词向量中
# snore-fest不存在于词向量中
# aboriginals不存在于词向量中
# shahids不存在于词向量中
# chomet不存在于词向量中
# curtizs不存在于词向量中
# movienot不存在于词向量中
# heroheroine不存在于词向量中
# yoshinaga不存在于词向量中
# watermans不存在于词向量中
# tolstoys不存在于词向量中
# demonstrative不存在于词向量中
# bohlen不存在于词向量中
# loessers不存在于词向量中
# riedelsheimer不存在于词向量中
# goin不存在于词向量中
# madeand不存在于词向量中
# aro不存在于词向量中
# hackmans不存在于词向量中
# es不存在于词向量中
# bards不存在于词向量中
# molla不存在于词向量中
# mjs不存在于词向量中
# amputee不存在于词向量中
# noahs不存在于词向量中
# $250不存在于词向量中
# 10the不存在于词向量中
# onin不存在于词向量中
# kazakos不存在于词向量中
# wtf!不存在于词向量中
# briny不存在于词向量中
# chriss不存在于词向量中
# videoi不存在于词向量中
# potentialthe不存在于词向量中
# goodtimes不存在于词向量中
# barrys不存在于词向量中
# dcom不存在于词向量中
# loti不存在于词向量中
# homefront不存在于词向量中
# lorettas不存在于词向量中
# cpt不存在于词向量中
# ferrells不存在于词向量中
# presidente不存在于词向量中
# neatness不存在于词向量中
# watchi不存在于词向量中
# mongolia不存在于词向量中
# overhyped不存在于词向量中
# cias不存在于词向量中
# borge不存在于词向量中
# writerthe不存在于词向量中
# convolutions不存在于词向量中
# glickenhaus不存在于词向量中
# birney不存在于词向量中
# gouald不存在于词向量中
# **spoilers**不存在于词向量中
# wowi不存在于词向量中
# adieu不存在于词向量中
# horrorthe不存在于词向量中
# liviens不存在于词向量中
# itno不存在于词向量中
# yanos不存在于词向量中
# bacalls不存在于词向量中
# voyagers不存在于词向量中
# lettieri不存在于词向量中
# eadie不存在于词向量中
# mules不存在于词向量中
# wella不存在于词向量中
# doa不存在于词向量中
# splat不存在于词向量中
# finishthe不存在于词向量中
# mindi不存在于词向量中
# showthis不存在于词向量中
# dumroo不存在于词向量中
# piovani不存在于词向量中
# trenchcoat不存在于词向量中
# madea不存在于词向量中
# actinga不存在于词向量中
# genoa不存在于词向量中
# dreama不存在于词向量中
# themwhat不存在于词向量中
# rainmaker不存在于词向量中
# catscratch不存在于词向量中
# lukass不存在于词向量中
# scenesthis不存在于词向量中
# olivers不存在于词向量中
# domini不存在于词向量中
# goldbergs不存在于词向量中
# worldthis不存在于词向量中
# cabals不存在于词向量中
# etcso不存在于词向量中
# belas不存在于词向量中
# directorthis不存在于词向量中
# showsthe不存在于词向量中
# gorethe不存在于词向量中
# gornick不存在于词向量中
# artemisias不存在于词向量中
# barek不存在于词向量中
# mallepa不存在于词向量中
# preacherman不存在于词向量中
# alsoi不存在于词向量中
# plotthis不存在于词向量中
# knowthis不存在于词向量中
# 70si不存在于词向量中
# deans不存在于词向量中
# scripti不存在于词向量中
# okeefe不存在于词向量中
# hadass不存在于词向量中
# kine不存在于词向量中
# stirbas不存在于词向量中
# pelletier不存在于词向量中
# hugsy不存在于词向量中
# kol不存在于词向量中
# tristans不存在于词向量中
# bernhards不存在于词向量中
# gnatpole不存在于词向量中
# tadashis不存在于词向量中
# film!!!!不存在于词向量中
# rushton不存在于词向量中
# itafter不存在于词向量中
# scotlands不存在于词向量中
# gonethe不存在于词向量中
# dentistry不存在于词向量中
# mitchells不存在于词向量中
# antonius不存在于词向量中
# thunderball不存在于词向量中
# burlinson不存在于词向量中
# isand不存在于词向量中
# hassie不存在于词向量中
# fancier不存在于词向量中
# disappointedthis不存在于词向量中
# minot不存在于词向量中
# linfield不存在于词向量中
# salo不存在于词向量中
# careys不存在于词向量中
# windman不存在于词向量中
# vette不存在于词向量中
# fl不存在于词向量中
# tuileries不存在于词向量中
# bigs不存在于词向量中
# suplexes不存在于词向量中
# lifeone不存在于词向量中
# monasterys不存在于词向量中
# roomthe不存在于词向量中
# powerthe不存在于词向量中
# non-existant不存在于词向量中
# grandpas不存在于词向量中
# mean!不存在于词向量中
# outin不存在于词向量中
# entanglement不存在于词向量中
# sinclairs不存在于词向量中
# prestons不存在于词向量中
# konvitz不存在于词向量中
# muchand不存在于词向量中
# mcgavins不存在于词向量中
# budgetthe不存在于词向量中
# pointthis不存在于词向量中
# tarrs不存在于词向量中
# charactersas不存在于词向量中
# molinas不存在于词向量中
# itsome不存在于词向量中
# `mr不存在于词向量中
# chehs不存在于词向量中
# amen不存在于词向量中
# dothis不存在于词向量中
# curlys不存在于词向量中
# mostels不存在于词向量中
# hepton不存在于词向量中
# aarons不存在于词向量中
# khakee不存在于词向量中
# isbut不存在于词向量中
# motherdaughter不存在于词向量中
# movieyes不存在于词向量中
# seachd不存在于词向量中
# eitherthis不存在于词向量中
# hanlon不存在于词向量中
# disappointedi不存在于词向量中
# goould不存在于词向量中
# abstractions不存在于词向量中
# aragami不存在于词向量中
# gérald不存在于词向量中
# vadas不存在于词向量中
# scenebut不存在于词向量中
# lighti不存在于词向量中
# jehovahs不存在于词向量中
# melchior不存在于词向量中
# showroom不存在于词向量中
# yakitate!不存在于词向量中
# +-不存在于词向量中
# herand不存在于词向量中
# endbut不存在于词向量中
# actordirector不存在于词向量中
# soll不存在于词向量中
# spiritualism不存在于词向量中
# grandsons不存在于词向量中
# roachs不存在于词向量中
# ladykillers不存在于词向量中
# chastened不存在于词向量中
# meand不存在于词向量中
# christophers不存在于词向量中
# thefts不存在于词向量中
# filmhowever不存在于词向量中
# missi不存在于词向量中
# heckerling不存在于词向量中
# interestingi不存在于词向量中
# castros不存在于词向量中
# yoshida不存在于词向量中
# endingthis不存在于词向量中
# itid不存在于词向量中
# lockes不存在于词向量中
# woah不存在于词向量中
# cuckold不存在于词向量中
# arisen不存在于词向量中
# homoeroticism不存在于词向量中
# bethere不存在于词向量中
# vampiros不存在于词向量中
# pertwees不存在于词向量中
# againin不存在于词向量中
# mats不存在于词向量中
# quintana不存在于词向量中
# likethe不存在于词向量中
# rheostatics不存在于词向量中
# werners不存在于词向量中
# dammit不存在于词向量中
# twos不存在于词向量中
# ferraris不存在于词向量中
# rivera不存在于词向量中
# sammis不存在于词向量中
# workand不存在于词向量中
# duchovnys不存在于词向量中
# fenwick不存在于词向量中
# shortthe不存在于词向量中
# descendents不存在于词向量中
# allif不存在于词向量中
# richies不存在于词向量中
# meh不存在于词向量中
# godfathers不存在于词向量中
# bulldozers不存在于词向量中
# beenthe不存在于词向量中
# donlan不存在于词向量中
# turaqistan不存在于词向量中
# meretricious不存在于词向量中
# zealanders不存在于词向量中
# cothk不存在于词向量中
# southampton不存在于词向量中
# gp不存在于词向量中
# trackersjourneymen!!不存在于词向量中
# paramilitaries不存在于词向量中
# renoirs不存在于词向量中
# lifeas不存在于词向量中
# wangs不存在于词向量中
# burrs不存在于词向量中
# haack不存在于词向量中
# amati不存在于词向量中
# coote不存在于词向量中
# martys不存在于词向量中
# lengles不存在于词向量中
# parn不存在于词向量中
# coincidently不存在于词向量中
# marjories不存在于词向量中
# schepisi不存在于词向量中
# evelyns不存在于词向量中
# ithowever不存在于词向量中
# trotter不存在于词向量中
# headthe不存在于词向量中
# watchedthe不存在于词向量中
# veils不存在于词向量中
# gummo不存在于词向量中
# childthis不存在于词向量中
# watling不存在于词向量中
# craigs不存在于词向量中
# fn不存在于词向量中
# bangladesh不存在于词向量中
# barnett不存在于词向量中
# alois不存在于词向量中
# playthe不存在于词向量中
# gokbakar不存在于词向量中
# talosians不存在于词向量中
# thunderbolt不存在于词向量中
# ariauna不存在于词向量中
# usas不存在于词向量中
# navel-gazing不存在于词向量中
# heflins不存在于词向量中
# gymnasium不存在于词向量中
# happenedi不存在于词向量中
# leonoras不存在于词向量中
# cullen不存在于词向量中
# cardos不存在于词向量中
# solino不存在于词向量中
# napoli不存在于词向量中
# razzle-dazzle不存在于词向量中
# allim不存在于词向量中
# hammerhead:不存在于词向量中
# non-event不存在于词向量中
# callan不存在于词向量中
# blackwhite不存在于词向量中
# extinguishers不存在于词向量中
# fixit不存在于词向量中
# beforei不存在于词向量中
# gingers不存在于词向量中
# ruge不存在于词向量中
# jew!不存在于词向量中
# erathe不存在于词向量中
# artthe不存在于词向量中
# catwalk不存在于词向量中
# kroko不存在于词向量中
# dresslers不存在于词向量中
# dialoguethe不存在于词向量中
# js不存在于词向量中
# torrances不存在于词向量中
# pratfall不存在于词向量中
# directorproducer不存在于词向量中
# levelthe不存在于词向量中
# ddt不存在于词向量中
# girlthe不存在于词向量中
# :-d不存在于词向量中
# inas不存在于词向量中
# timeso不存在于词向量中
# storyits不存在于词向量中
# reflexes不存在于词向量中
# winslets不存在于词向量中
# barneys不存在于词向量中
# word!不存在于词向量中
# lancasters不存在于词向量中
# altair不存在于词向量中
# dansu不存在于词向量中
# tommys不存在于词向量中
# culkins不存在于词向量中
# owni不存在于词向量中
# tesis不存在于词向量中
# rivendell不存在于词向量中
# zimmers不存在于词向量中
# jobi不存在于词向量中
# sequencethe不存在于词向量中
# scarman不存在于词向量中
# bungalow不存在于词向量中
# ashleys不存在于词向量中
# uranus不存在于词向量中
# reveres不存在于词向量中
# domergues不存在于词向量中
# chabon不存在于词向量中
# himits不存在于词向量中
# watchingi不存在于词向量中
# boththe不存在于词向量中
# proog不存在于词向量中
# madethis不存在于词向量中
# murdersthe不存在于词向量中
# cervera不存在于词向量中
# schrieber不存在于词向量中
# ick不存在于词向量中
# don-del-oro不存在于词向量中
# cinematograph不存在于词向量中
# philanthropist不存在于词向量中
# hubbys不存在于词向量中
# worldas不存在于词向量中
# trelkovskys不存在于词向量中
# conchata不存在于词向量中
# charactersthis不存在于词向量中
# pace!不存在于词向量中
# 666:不存在于词向量中
# $12000000不存在于词向量中
# mechs不存在于词向量中
# ajas不存在于词向量中
# matts不存在于词向量中
# valcos不存在于词向量中
# iton不存在于词向量中
# fedja不存在于词向量中
# abigails不存在于词向量中
# bushs不存在于词向量中
# etzel不存在于词向量中
# emotionthe不存在于词向量中
# ebsen不存在于词向量中
# petiots不存在于词向量中
# cubas不存在于词向量中
# db不存在于词向量中
# matchthe不存在于词向量中
# haarman不存在于词向量中
# saskatchewan不存在于词向量中
# père-lachaise不存在于词向量中
# setthe不存在于词向量中
# top-quality不存在于词向量中
# alzheimers不存在于词向量中
# peptides不存在于词向量中
# republics不存在于词向量中
# obrian不存在于词向量中
# flawsthe不存在于词向量中
# testa不存在于词向量中
# tingler不存在于词向量中
# muchif不存在于词向量中
# 07不存在于词向量中
# brideshead不存在于词向量中
# anands不存在于词向量中
# acorn不存在于词向量中
# zenias不存在于词向量中
# filmwith不存在于词向量中
# showand不存在于词向量中
# isotopes不存在于词向量中
# calvins不存在于词向量中
# annemarie不存在于词向量中
# gruel不存在于词向量中
# thatin不存在于词向量中
# tykwers不存在于词向量中
# show-off不存在于词向量中
# mir不存在于词向量中
# asgard不存在于词向量中
# http:wwwpetitiononlinecomgh1215petitionhtml不存在于词向量中
# hereand不存在于词向量中
# yodas不存在于词向量中
# groovin不存在于词向量中
# luminescence不存在于词向量中
# storyas不存在于词向量中
# wiseman不存在于词向量中
# spoonful不存在于词向量中
# worsei不存在于词向量中
# hara不存在于词向量中
# lamia不存在于词向量中
# moviesso不存在于词向量中
# f-不存在于词向量中
# waya不存在于词向量中
# blachere不存在于词向量中
# mckees不存在于词向量中
# schepisis不存在于词向量中
# wayif不存在于词向量中
# frollo不存在于词向量中

# %%
print("train data shape: {}".format(data.trainReviews.shape))
print("train label shape: {}".format(data.trainLabels.shape))
print("eval data shape: {}".format(data.evalReviews.shape))
type(data)
data.trainReviews
data.trainLabels
# Out:
# train data shape: (20000, 200)
# train label shape: (20000,)
# eval data shape: (5000, 200)
# array([1., 1., 0., ..., 0., 0., 0.], dtype=float32)

# %%
# 输出batch数据集

def nextBatch(x, y, batchSize):
        """
        生成batch数据集，用生成器的方式输出
        """
    
        perm = np.arange(len(x))
        np.random.shuffle(perm)
        x = x[perm]
        y = y[perm]
        
        numBatches = len(x) // batchSize

        for i in range(numBatches):
            start = i * batchSize
            end = start + batchSize
            batchX = np.array(x[start: end], dtype="int64")
            batchY = np.array(y[start: end], dtype="float32")
            
            yield batchX, batchY

# %%
# 构建模型
class TextCNN(object):
    """
    Text CNN 用于文本分类
    """
    def __init__(self, config, wordEmbedding):

        # 定义模型的输入
        self.inputX = tf.placeholder(tf.int32, [None, config.sequenceLength], name="inputX")
        self.inputY = tf.placeholder(tf.int32, [None], name="inputY")
        
        self.dropoutKeepProb = tf.placeholder(tf.float32, name="dropoutKeepProb")
        
        # 定义l2损失
        l2Loss = tf.constant(0.0)
        
        # 词嵌入层
        with tf.name_scope("embedding"):

            # 利用预训练的词向量初始化词嵌入矩阵
            self.W = tf.Variable(tf.cast(wordEmbedding, dtype=tf.float32, name="word2vec") ,name="W")
            # 利用词嵌入矩阵将输入的数据中的词转换成词向量，维度[batch_size, sequence_length, embedding_size]
            self.embeddedWords = tf.nn.embedding_lookup(self.W, self.inputX)
            # 卷积的输入是思维[batch_size, width, height, channel]，因此需要增加维度，用tf.expand_dims来增大维度
            self.embeddedWordsExpanded = tf.expand_dims(self.embeddedWords, -1)

        # 创建卷积和池化层
        pooledOutputs = []
        # 有三种size的filter，3， 4， 5，textCNN是个多通道单层卷积的模型，可以看作三个单层的卷积模型的融合
        for i, filterSize in enumerate(config.model.filterSizes):
            with tf.name_scope("conv-maxpool-%s" % filterSize):
                # 卷积层，卷积核尺寸为filterSize * embeddingSize，卷积核的个数为numFilters
                # 初始化权重矩阵和偏置
                filterShape = [filterSize, config.model.embeddingSize, 1, config.model.numFilters]
                W = tf.Variable(tf.truncated_normal(filterShape, stddev=0.1), name="W")
                b = tf.Variable(tf.constant(0.1, shape=[config.model.numFilters]), name="b")
                conv = tf.nn.conv2d(
                    self.embeddedWordsExpanded,
                    W,
                    strides=[1, 1, 1, 1],
                    padding="VALID",
                    name="conv")
                
                # relu函数的非线性映射
                h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                
                # 池化层，最大池化，池化是对卷积后的序列取一个最大值
                pooled = tf.nn.max_pool(
                    h,
                    ksize=[1, config.sequenceLength - filterSize + 1, 1, 1],  # ksize shape: [batch, height, width, channels]
                    strides=[1, 1, 1, 1],
                    padding='VALID',
                    name="pool")
                pooledOutputs.append(pooled)  # 将三种size的filter的输出一起加入到列表中

        # 得到CNN网络的输出长度
        numFiltersTotal = config.model.numFilters * len(config.model.filterSizes)
        
        # 池化后的维度不变，按照最后的维度channel来concat
        self.hPool = tf.concat(pooledOutputs, 3)
        
        # 摊平成二维的数据输入到全连接层
        self.hPoolFlat = tf.reshape(self.hPool, [-1, numFiltersTotal])

        # dropout
        with tf.name_scope("dropout"):
            self.hDrop = tf.nn.dropout(self.hPoolFlat, self.dropoutKeepProb)
       
        # 全连接层的输出
        with tf.name_scope("output"):
            outputW = tf.get_variable(
                "outputW",
                shape=[numFiltersTotal, config.numClasses],
                initializer=tf.contrib.layers.xavier_initializer())
            outputB= tf.Variable(tf.constant(0.1, shape=[config.numClasses]), name="outputB")
            l2Loss += tf.nn.l2_loss(outputW)
            l2Loss += tf.nn.l2_loss(outputB)
            self.logits = tf.nn.xw_plus_b(self.hDrop, outputW, outputB, name="logits")
            if config.numClasses == 1:
                self.predictions = tf.cast(tf.greater_equal(self.logits, 0.0), tf.int32, name="predictions")
            elif config.numClasses > 1:
                self.predictions = tf.argmax(self.logits, axis=-1, name="predictions")
            
            print(self.predictions)
        
        # 计算二元交叉熵损失
        with tf.name_scope("loss"):
            
            if config.numClasses == 1:
                losses = tf.nn.sigmoid_cross_entropy_with_logits(logits=self.logits, labels=tf.cast(tf.reshape(self.inputY, [-1, 1]), 
                                                                                                    dtype=tf.float32))
            elif config.numClasses > 1:
                losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=self.logits, labels=self.inputY)
                
            self.loss = tf.reduce_mean(losses) + config.model.l2RegLambda * l2Loss

# %%
"""
定义各类性能指标
"""

def mean(item: list) -> float:
    """
    计算列表中元素的平均值
    :param item: 列表对象
    :return:
    """
    res = sum(item) / len(item) if len(item) > 0 else 0
    return res


def accuracy(pred_y, true_y):
    """
    计算二类和多类的准确率
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :return:
    """
    if isinstance(pred_y[0], list):
        pred_y = [item[0] for item in pred_y]
    corr = 0
    for i in range(len(pred_y)):
        if pred_y[i] == true_y[i]:
            corr += 1
    acc = corr / len(pred_y) if len(pred_y) > 0 else 0
    return acc


def binary_precision(pred_y, true_y, positive=1):
    """
    二类的精确率计算
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :param positive: 正例的索引表示
    :return:
    """
    corr = 0
    pred_corr = 0
    for i in range(len(pred_y)):
        if pred_y[i] == positive:
            pred_corr += 1
            if pred_y[i] == true_y[i]:
                corr += 1

    prec = corr / pred_corr if pred_corr > 0 else 0
    return prec


def binary_recall(pred_y, true_y, positive=1):
    """
    二类的召回率
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :param positive: 正例的索引表示
    :return:
    """
    corr = 0
    true_corr = 0
    for i in range(len(pred_y)):
        if true_y[i] == positive:
            true_corr += 1
            if pred_y[i] == true_y[i]:
                corr += 1

    rec = corr / true_corr if true_corr > 0 else 0
    return rec


def binary_f_beta(pred_y, true_y, beta=1.0, positive=1):
    """
    二类的f beta值
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :param beta: beta值
    :param positive: 正例的索引表示
    :return:
    """
    precision = binary_precision(pred_y, true_y, positive)
    recall = binary_recall(pred_y, true_y, positive)
    try:
        f_b = (1 + beta * beta) * precision * recall / (beta * beta * precision + recall)
    except:
        f_b = 0
    return f_b


def multi_precision(pred_y, true_y, labels):
    """
    多类的精确率
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :param labels: 标签列表
    :return:
    """
    if isinstance(pred_y[0], list):
        pred_y = [item[0] for item in pred_y]

    precisions = [binary_precision(pred_y, true_y, label) for label in labels]
    prec = mean(precisions)
    return prec


def multi_recall(pred_y, true_y, labels):
    """
    多类的召回率
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :param labels: 标签列表
    :return:
    """
    if isinstance(pred_y[0], list):
        pred_y = [item[0] for item in pred_y]

    recalls = [binary_recall(pred_y, true_y, label) for label in labels]
    rec = mean(recalls)
    return rec


def multi_f_beta(pred_y, true_y, labels, beta=1.0):
    """
    多类的f beta值
    :param pred_y: 预测结果
    :param true_y: 真实结果
    :param labels: 标签列表
    :param beta: beta值
    :return:
    """
    if isinstance(pred_y[0], list):
        pred_y = [item[0] for item in pred_y]

    f_betas = [binary_f_beta(pred_y, true_y, beta, label) for label in labels]
    f_beta = mean(f_betas)
    return f_beta


def get_binary_metrics(pred_y, true_y, f_beta=1.0):
    """
    得到二分类的性能指标
    :param pred_y:
    :param true_y:
    :param f_beta:
    :return:
    """
    acc = accuracy(pred_y, true_y)
    recall = binary_recall(pred_y, true_y)
    precision = binary_precision(pred_y, true_y)
    f_beta = binary_f_beta(pred_y, true_y, f_beta)
    return acc, recall, precision, f_beta


def get_multi_metrics(pred_y, true_y, labels, f_beta=1.0):
    """
    得到多分类的性能指标
    :param pred_y:
    :param true_y:
    :param labels:
    :param f_beta:
    :return:
    """
    acc = accuracy(pred_y, true_y)
    recall = multi_recall(pred_y, true_y, labels)
    precision = multi_precision(pred_y, true_y, labels)
    f_beta = multi_f_beta(pred_y, true_y, labels, f_beta)
    return acc, recall, precision, f_beta

# %%
# 训练模型

# 生成训练集和验证集
trainReviews = data.trainReviews
trainLabels = data.trainLabels
evalReviews = data.evalReviews
evalLabels = data.evalLabels

wordEmbedding = data.wordEmbedding
labelList = data.labelList

# 定义计算图
with tf.Graph().as_default():

    session_conf = tf.ConfigProto(allow_soft_placement=True, log_device_placement=False)
    session_conf.gpu_options.allow_growth=True
    session_conf.gpu_options.per_process_gpu_memory_fraction = 0.6  # 配置gpu占用率  

    sess = tf.Session(config=session_conf)
    
    # 定义会话
    with sess.as_default():
        cnn = TextCNN(config, wordEmbedding)
        
        globalStep = tf.Variable(0, name="globalStep", trainable=False)
        # 定义优化函数，传入学习速率参数
        optimizer = tf.train.AdamOptimizer(config.training.learningRate)
        # 计算梯度,得到梯度和变量
        gradsAndVars = optimizer.compute_gradients(cnn.loss)
        # 将梯度应用到变量下，生成训练器
        trainOp = optimizer.apply_gradients(gradsAndVars, global_step=globalStep)
        
        # 用summary绘制tensorBoard
        gradSummaries = []
        for g, v in gradsAndVars:
            if g is not None:
                tf.summary.histogram("{}/grad/hist".format(v.name), g)
                tf.summary.scalar("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
        
        outDir = os.path.abspath(os.path.join(os.path.curdir, "summarys"))
        print("Writing to {}\n".format(outDir))
        
        lossSummary = tf.summary.scalar("loss", cnn.loss)
        summaryOp = tf.summary.merge_all()
        
        trainSummaryDir = os.path.join(outDir, "train")
        trainSummaryWriter = tf.summary.FileWriter(trainSummaryDir, sess.graph)
        
        evalSummaryDir = os.path.join(outDir, "eval")
        evalSummaryWriter = tf.summary.FileWriter(evalSummaryDir, sess.graph)
        
        
        # 初始化所有变量
        saver = tf.train.Saver(tf.global_variables(), max_to_keep=5)
        
        # 保存模型的一种方式，保存为pb文件
        savedModelPath = "../model/textCNN/savedModel"
        if os.path.exists(savedModelPath):
            os.rmdir(savedModelPath)
        builder = tf.saved_model.builder.SavedModelBuilder(savedModelPath)
            
        sess.run(tf.global_variables_initializer())

        def trainStep(batchX, batchY):
            """
            训练函数
            """   
            feed_dict = {
              cnn.inputX: batchX,
              cnn.inputY: batchY,
              cnn.dropoutKeepProb: config.model.dropoutKeepProb
            }
            _, summary, step, loss, predictions = sess.run(
                [trainOp, summaryOp, globalStep, cnn.loss, cnn.predictions],
                feed_dict)
            timeStr = datetime.datetime.now().isoformat()
            
            if config.numClasses == 1:
                acc, recall, prec, f_beta = get_binary_metrics(pred_y=predictions, true_y=batchY)

                
            elif config.numClasses > 1:
                acc, recall, prec, f_beta = get_multi_metrics(pred_y=predictions, true_y=batchY,
                                                              labels=labelList)
                
            trainSummaryWriter.add_summary(summary, step)
            
            return loss, acc, prec, recall, f_beta

        def devStep(batchX, batchY):
            """
            验证函数
            """
            feed_dict = {
              cnn.inputX: batchX,
              cnn.inputY: batchY,
              cnn.dropoutKeepProb: 1.0
            }
            summary, step, loss, predictions = sess.run(
                [summaryOp, globalStep, cnn.loss, cnn.predictions],
                feed_dict)
            
            if config.numClasses == 1:
            
                acc, precision, recall, f_beta = get_binary_metrics(pred_y=predictions, true_y=batchY)
            elif config.numClasses > 1:
                acc, precision, recall, f_beta = get_multi_metrics(pred_y=predictions, true_y=batchY, labels=labelList)
            
            evalSummaryWriter.add_summary(summary, step)
            
            return loss, acc, precision, recall, f_beta
        
        for i in range(config.training.epoches):
            # 训练模型
            print("start training model")
            for batchTrain in nextBatch(trainReviews, trainLabels, config.batchSize):
                loss, acc, prec, recall, f_beta = trainStep(batchTrain[0], batchTrain[1])
                
                currentStep = tf.train.global_step(sess, globalStep) 
                print("train: step: {}, loss: {}, acc: {}, recall: {}, precision: {}, f_beta: {}".format(
                    currentStep, loss, acc, recall, prec, f_beta))
                if currentStep % config.training.evaluateEvery == 0:
                    print("\nEvaluation:")
                    
                    losses = []
                    accs = []
                    f_betas = []
                    precisions = []
                    recalls = []
                    
                    for batchEval in nextBatch(evalReviews, evalLabels, config.batchSize):
                        loss, acc, precision, recall, f_beta = devStep(batchEval[0], batchEval[1])
                        losses.append(loss)
                        accs.append(acc)
                        f_betas.append(f_beta)
                        precisions.append(precision)
                        recalls.append(recall)
                        
                    time_str = datetime.datetime.now().isoformat()
                    print("{}, step: {}, loss: {}, acc: {},precision: {}, recall: {}, f_beta: {}".format(time_str, currentStep, mean(losses), 
                                                                                                       mean(accs), mean(precisions),
                                                                                                       mean(recalls), mean(f_betas)))
                    
                if currentStep % config.training.checkpointEvery == 0:
                    # 保存模型的另一种方法，保存checkpoint文件
                    path = saver.save(sess, "../model/textCNN", global_step=currentStep)
                    print("Saved model checkpoint to {}\n".format(path))
                    
        inputs = {"inputX": tf.saved_model.utils.build_tensor_info(cnn.inputX),
                  "keepProb": tf.saved_model.utils.build_tensor_info(cnn.dropoutKeepProb)}

        outputs = {"predictions": tf.saved_model.utils.build_tensor_info(cnn.predictions)}

        prediction_signature = tf.saved_model.signature_def_utils.build_signature_def(inputs=inputs, outputs=outputs,
                                                                                      method_name=tf.saved_model.signature_constants.PREDICT_METHOD_NAME)
        legacy_init_op = tf.group(tf.tables_initializer(), name="legacy_init_op")
        builder.add_meta_graph_and_variables(sess, [tf.saved_model.tag_constants.SERVING],
                                            signature_def_map={"predict": prediction_signature}, legacy_init_op=legacy_init_op)

        builder.save()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 14:04:09.657838 140058595800832 deprecation.py:506] From <ipython-input-23-32f6413f910e>:67: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0726 14:04:10.461930 140058595800832 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0726 14:04:10.484984 140058595800832 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Tensor("output/predictions:0", shape=(?, 1), dtype=int32)
# Writing to /home/jqxx/jupyternotebook/textClassifier-master/textCNN/summarys
#
# start training model
# train: step: 1, loss: 1.6475231647491455, acc: 0.5546875, recall: 0.47368421052631576, precision: 0.5, f_beta: 0.4864864864864865
# train: step: 2, loss: 1.501197338104248, acc: 0.5, recall: 0.5806451612903226, precision: 0.4864864864864865, f_beta: 0.5294117647058824
# train: step: 3, loss: 1.5962328910827637, acc: 0.515625, recall: 0.24242424242424243, precision: 0.5714285714285714, f_beta: 0.3404255319148936
# train: step: 4, loss: 1.1230379343032837, acc: 0.6171875, recall: 0.6506024096385542, precision: 0.7297297297297297, f_beta: 0.6878980891719745
# train: step: 5, loss: 1.8734443187713623, acc: 0.5390625, recall: 0.9178082191780822, precision: 0.5583333333333333, f_beta: 0.694300518134715
# train: step: 6, loss: 1.9405497312545776, acc: 0.5078125, recall: 0.8688524590163934, precision: 0.49074074074074076, f_beta: 0.6272189349112426
# train: step: 7, loss: 1.592843770980835, acc: 0.4453125, recall: 0.5, precision: 0.4084507042253521, f_beta: 0.4496124031007752
# train: step: 8, loss: 1.906559944152832, acc: 0.53125, recall: 0.26229508196721313, precision: 0.5161290322580645, f_beta: 0.34782608695652173
# train: step: 9, loss: 1.9278879165649414, acc: 0.515625, recall: 0.140625, precision: 0.5625, f_beta: 0.225
# train: step: 10, loss: 1.4762561321258545, acc: 0.6015625, recall: 0.21153846153846154, precision: 0.5238095238095238, f_beta: 0.3013698630136986
# train: step: 11, loss: 1.670665979385376, acc: 0.46875, recall: 0.3709677419354839, precision: 0.4423076923076923, f_beta: 0.4035087719298246
# train: step: 12, loss: 1.3967260122299194, acc: 0.515625, recall: 0.5806451612903226, precision: 0.5, f_beta: 0.537313432835821
# train: step: 13, loss: 1.816192865371704, acc: 0.46875, recall: 0.7666666666666667, precision: 0.46, f_beta: 0.575
# train: step: 14, loss: 1.8373993635177612, acc: 0.46875, recall: 0.7017543859649122, precision: 0.43956043956043955, f_beta: 0.5405405405405405
# train: step: 15, loss: 1.3991708755493164, acc: 0.53125, recall: 0.6615384615384615, precision: 0.5308641975308642, f_beta: 0.589041095890411
# train: step: 16, loss: 1.1434683799743652, acc: 0.5234375, recall: 0.5774647887323944, precision: 0.5694444444444444, f_beta: 0.5734265734265734
# train: step: 17, loss: 1.3526451587677002, acc: 0.5234375, recall: 0.423728813559322, precision: 0.4807692307692308, f_beta: 0.45045045045045046
# train: step: 18, loss: 1.594193458557129, acc: 0.53125, recall: 0.30303030303030304, precision: 0.5882352941176471, f_beta: 0.39999999999999997
# train: step: 19, loss: 1.6260274648666382, acc: 0.53125, recall: 0.3717948717948718, precision: 0.725, f_beta: 0.49152542372881347
# train: step: 20, loss: 1.3589885234832764, acc: 0.5703125, recall: 0.5068493150684932, precision: 0.6607142857142857, f_beta: 0.5736434108527132
# train: step: 21, loss: 1.1207690238952637, acc: 0.5703125, recall: 0.6307692307692307, precision: 0.5694444444444444, f_beta: 0.5985401459854014
# train: step: 22, loss: 1.5927753448486328, acc: 0.46875, recall: 0.8360655737704918, precision: 0.46788990825688076, f_beta: 0.6
# train: step: 23, loss: 1.7203090190887451, acc: 0.5, recall: 0.7213114754098361, precision: 0.4835164835164835, f_beta: 0.5789473684210528
# train: step: 24, loss: 1.4904611110687256, acc: 0.5, recall: 0.6911764705882353, precision: 0.5222222222222223, f_beta: 0.5949367088607594
# train: step: 25, loss: 1.257702350616455, acc: 0.5625, recall: 0.6176470588235294, precision: 0.5833333333333334, f_beta: 0.6
# train: step: 26, loss: 1.4838627576828003, acc: 0.4921875, recall: 0.3783783783783784, precision: 0.5957446808510638, f_beta: 0.4628099173553719
# train: step: 27, loss: 1.3976964950561523, acc: 0.515625, recall: 0.38235294117647056, precision: 0.5652173913043478, f_beta: 0.45614035087719296
# train: step: 28, loss: 1.0589900016784668, acc: 0.578125, recall: 0.3508771929824561, precision: 0.5405405405405406, f_beta: 0.425531914893617
# train: step: 29, loss: 0.8988327383995056, acc: 0.6171875, recall: 0.5, precision: 0.5102040816326531, f_beta: 0.5050505050505051
# train: step: 30, loss: 1.3119456768035889, acc: 0.5, recall: 0.37142857142857144, precision: 0.5652173913043478, f_beta: 0.4482758620689655
# train: step: 31, loss: 1.0801447629928589, acc: 0.53125, recall: 0.6142857142857143, precision: 0.5657894736842105, f_beta: 0.5890410958904109
# train: step: 32, loss: 1.2775659561157227, acc: 0.546875, recall: 0.631578947368421, precision: 0.4931506849315068, f_beta: 0.5538461538461539
# train: step: 33, loss: 1.3016139268875122, acc: 0.5, recall: 0.7, precision: 0.4772727272727273, f_beta: 0.5675675675675677
# train: step: 34, loss: 1.1942367553710938, acc: 0.5390625, recall: 0.6333333333333333, precision: 0.5066666666666667, f_beta: 0.5629629629629629
# train: step: 35, loss: 1.007637619972229, acc: 0.5703125, recall: 0.6, precision: 0.5735294117647058, f_beta: 0.5864661654135338
# train: step: 36, loss: 1.036776065826416, acc: 0.5390625, recall: 0.3880597014925373, precision: 0.5909090909090909, f_beta: 0.46846846846846846
# train: step: 37, loss: 1.3169004917144775, acc: 0.4921875, recall: 0.3382352941176471, precision: 0.5348837209302325, f_beta: 0.4144144144144144
# train: step: 38, loss: 1.1757432222366333, acc: 0.5703125, recall: 0.45714285714285713, precision: 0.6530612244897959, f_beta: 0.53781512605042
# train: step: 39, loss: 0.8326148986816406, acc: 0.6328125, recall: 0.6716417910447762, precision: 0.6428571428571429, f_beta: 0.6569343065693432
# train: step: 40, loss: 0.9547973871231079, acc: 0.5625, recall: 0.65, precision: 0.527027027027027, f_beta: 0.5820895522388059
# train: step: 41, loss: 1.073439121246338, acc: 0.5078125, recall: 0.6268656716417911, precision: 0.525, f_beta: 0.5714285714285715
# train: step: 42, loss: 0.9862905144691467, acc: 0.59375, recall: 0.703125, precision: 0.5769230769230769, f_beta: 0.6338028169014084
# train: step: 43, loss: 0.9811147451400757, acc: 0.5703125, recall: 0.6190476190476191, precision: 0.5571428571428572, f_beta: 0.5864661654135339
# train: step: 44, loss: 0.8958688974380493, acc: 0.6328125, recall: 0.6065573770491803, precision: 0.6166666666666667, f_beta: 0.6115702479338844
# train: step: 45, loss: 1.0430891513824463, acc: 0.5546875, recall: 0.4126984126984127, precision: 0.5652173913043478, f_beta: 0.4770642201834862
# train: step: 46, loss: 0.865032434463501, acc: 0.578125, recall: 0.5352112676056338, precision: 0.6440677966101694, f_beta: 0.5846153846153846
# train: step: 47, loss: 0.8022765517234802, acc: 0.6796875, recall: 0.625, precision: 0.7017543859649122, f_beta: 0.6611570247933884
# train: step: 48, loss: 0.8807299733161926, acc: 0.6015625, recall: 0.5774647887323944, precision: 0.6612903225806451, f_beta: 0.6165413533834587
# train: step: 49, loss: 0.9769765138626099, acc: 0.5546875, recall: 0.6739130434782609, precision: 0.4246575342465753, f_beta: 0.5210084033613445
# train: step: 50, loss: 0.830336332321167, acc: 0.578125, recall: 0.5285714285714286, precision: 0.6379310344827587, f_beta: 0.5781249999999999
# train: step: 51, loss: 0.9437643885612488, acc: 0.625, recall: 0.6911764705882353, precision: 0.6351351351351351, f_beta: 0.6619718309859154
# train: step: 52, loss: 0.8439900875091553, acc: 0.578125, recall: 0.6567164179104478, precision: 0.5866666666666667, f_beta: 0.619718309859155
# train: step: 53, loss: 0.8967363834381104, acc: 0.5703125, recall: 0.6376811594202898, precision: 0.5945945945945946, f_beta: 0.6153846153846154
# train: step: 54, loss: 0.9640591740608215, acc: 0.5703125, recall: 0.6521739130434783, precision: 0.5921052631578947, f_beta: 0.6206896551724137
# train: step: 55, loss: 0.9563848972320557, acc: 0.546875, recall: 0.4262295081967213, precision: 0.5306122448979592, f_beta: 0.4727272727272728
# train: step: 56, loss: 0.906165361404419, acc: 0.5703125, recall: 0.5161290322580645, precision: 0.5614035087719298, f_beta: 0.5378151260504201
# train: step: 57, loss: 0.7414604425430298, acc: 0.6171875, recall: 0.609375, precision: 0.6190476190476191, f_beta: 0.6141732283464567
# train: step: 58, loss: 0.7247345447540283, acc: 0.6484375, recall: 0.7246376811594203, precision: 0.6578947368421053, f_beta: 0.689655172413793
# train: step: 59, loss: 0.8931604623794556, acc: 0.6171875, recall: 0.6875, precision: 0.6027397260273972, f_beta: 0.6423357664233577
# train: step: 60, loss: 0.8508222103118896, acc: 0.5859375, recall: 0.6307692307692307, precision: 0.5857142857142857, f_beta: 0.6074074074074074
# train: step: 61, loss: 0.7002382278442383, acc: 0.65625, recall: 0.7681159420289855, precision: 0.654320987654321, f_beta: 0.7066666666666667
# train: step: 62, loss: 0.6984703540802002, acc: 0.6015625, recall: 0.6212121212121212, precision: 0.6119402985074627, f_beta: 0.6165413533834586
# train: step: 63, loss: 0.7978183031082153, acc: 0.59375, recall: 0.639344262295082, precision: 0.5652173913043478, f_beta: 0.6000000000000001
# train: step: 64, loss: 0.743649959564209, acc: 0.5859375, recall: 0.5757575757575758, precision: 0.6031746031746031, f_beta: 0.5891472868217055
# train: step: 65, loss: 0.7123292684555054, acc: 0.640625, recall: 0.6065573770491803, precision: 0.6271186440677966, f_beta: 0.6166666666666666
# train: step: 66, loss: 0.7724729776382446, acc: 0.6171875, recall: 0.5633802816901409, precision: 0.6896551724137931, f_beta: 0.6201550387596899
# train: step: 67, loss: 0.7205559015274048, acc: 0.6875, recall: 0.6363636363636364, precision: 0.7241379310344828, f_beta: 0.6774193548387097
# train: step: 68, loss: 0.7291417121887207, acc: 0.6953125, recall: 0.6935483870967742, precision: 0.6825396825396826, f_beta: 0.6880000000000001
# train: step: 69, loss: 0.7580624222755432, acc: 0.625, recall: 0.6333333333333333, precision: 0.59375, f_beta: 0.6129032258064516
# train: step: 70, loss: 0.6765493750572205, acc: 0.671875, recall: 0.7868852459016393, precision: 0.6233766233766234, f_beta: 0.6956521739130435
# train: step: 71, loss: 0.8462231755256653, acc: 0.640625, recall: 0.7230769230769231, precision: 0.6266666666666667, f_beta: 0.6714285714285715
# train: step: 72, loss: 0.7467052936553955, acc: 0.625, recall: 0.5789473684210527, precision: 0.7333333333333333, f_beta: 0.6470588235294117
# train: step: 73, loss: 0.6955350637435913, acc: 0.640625, recall: 0.5818181818181818, precision: 0.5818181818181818, f_beta: 0.5818181818181818
# train: step: 74, loss: 0.7635359764099121, acc: 0.5859375, recall: 0.625, precision: 0.5797101449275363, f_beta: 0.6015037593984963
# train: step: 75, loss: 0.7860304117202759, acc: 0.59375, recall: 0.4857142857142857, precision: 0.68, f_beta: 0.5666666666666667
# train: step: 76, loss: 0.7414606809616089, acc: 0.6484375, recall: 0.6081081081081081, precision: 0.7377049180327869, f_beta: 0.6666666666666667
# train: step: 77, loss: 0.7654452323913574, acc: 0.625, recall: 0.7142857142857143, precision: 0.6, f_beta: 0.6521739130434783
# train: step: 78, loss: 0.6991228461265564, acc: 0.6875, recall: 0.8205128205128205, precision: 0.7111111111111111, f_beta: 0.7619047619047619
# train: step: 79, loss: 0.6124736666679382, acc: 0.703125, recall: 0.8392857142857143, precision: 0.618421052631579, f_beta: 0.7121212121212123
# train: step: 80, loss: 0.6500732898712158, acc: 0.640625, recall: 0.8, precision: 0.5853658536585366, f_beta: 0.676056338028169
# train: step: 81, loss: 0.7341070771217346, acc: 0.671875, recall: 0.6428571428571429, precision: 0.6206896551724138, f_beta: 0.6315789473684211
# train: step: 82, loss: 0.7368839383125305, acc: 0.6328125, recall: 0.5084745762711864, precision: 0.625, f_beta: 0.5607476635514018
# train: step: 83, loss: 0.7650858163833618, acc: 0.625, recall: 0.3787878787878788, precision: 0.78125, f_beta: 0.510204081632653
# train: step: 84, loss: 0.7565670013427734, acc: 0.6484375, recall: 0.5079365079365079, precision: 0.6956521739130435, f_beta: 0.5871559633027522
# train: step: 85, loss: 0.512991189956665, acc: 0.7734375, recall: 0.6923076923076923, precision: 0.7346938775510204, f_beta: 0.7128712871287128
# train: step: 86, loss: 0.6675400733947754, acc: 0.671875, recall: 0.625, precision: 0.625, f_beta: 0.625
# train: step: 87, loss: 0.5515706539154053, acc: 0.7265625, recall: 0.8088235294117647, precision: 0.7142857142857143, f_beta: 0.7586206896551725
# train: step: 88, loss: 0.5956258773803711, acc: 0.734375, recall: 0.75, precision: 0.75, f_beta: 0.75
# train: step: 89, loss: 0.6165528297424316, acc: 0.6640625, recall: 0.7101449275362319, precision: 0.6805555555555556, f_beta: 0.6950354609929078
# train: step: 90, loss: 0.6213805675506592, acc: 0.734375, recall: 0.8666666666666667, precision: 0.7303370786516854, f_beta: 0.7926829268292682
# train: step: 91, loss: 0.6055978536605835, acc: 0.71875, recall: 0.8064516129032258, precision: 0.6756756756756757, f_beta: 0.7352941176470588
# train: step: 92, loss: 0.6285834312438965, acc: 0.6953125, recall: 0.7358490566037735, precision: 0.609375, f_beta: 0.6666666666666665
# train: step: 93, loss: 0.6461730003356934, acc: 0.6328125, recall: 0.6166666666666667, precision: 0.6065573770491803, f_beta: 0.6115702479338844
# train: step: 94, loss: 0.6576992273330688, acc: 0.6875, recall: 0.4406779661016949, precision: 0.7878787878787878, f_beta: 0.5652173913043478
# train: step: 95, loss: 0.5751754641532898, acc: 0.7421875, recall: 0.5396825396825397, precision: 0.8947368421052632, f_beta: 0.6732673267326732
# train: step: 96, loss: 0.639553964138031, acc: 0.6953125, recall: 0.5517241379310345, precision: 0.7111111111111111, f_beta: 0.6213592233009709
# train: step: 97, loss: 0.5757347941398621, acc: 0.7265625, recall: 0.6909090909090909, precision: 0.6785714285714286, f_beta: 0.6846846846846847
# train: step: 98, loss: 0.6324270367622375, acc: 0.703125, recall: 0.6875, precision: 0.7096774193548387, f_beta: 0.6984126984126984
# train: step: 99, loss: 0.7092083692550659, acc: 0.6875, recall: 0.7903225806451613, precision: 0.6447368421052632, f_beta: 0.7101449275362319
# train: step: 100, loss: 0.5099948048591614, acc: 0.7578125, recall: 0.8260869565217391, precision: 0.75, f_beta: 0.786206896551724
#
# Evaluation:
# 2019-07-26T14:04:45.950688, step: 100, loss: 0.45994821114417833, acc: 0.7920673076923077,precision: 0.8975852770613394, recall: 0.7444153561428506, f_beta: 0.8127323490855775
# Saved model checkpoint to ../model/textCNN-100
#
# train: step: 101, loss: 0.7468768358230591, acc: 0.625, recall: 0.7166666666666667, precision: 0.581081081081081, f_beta: 0.6417910447761194
# train: step: 102, loss: 0.6194909811019897, acc: 0.703125, recall: 0.6935483870967742, precision: 0.6935483870967742, f_beta: 0.6935483870967742
# train: step: 103, loss: 0.5662726163864136, acc: 0.765625, recall: 0.78125, precision: 0.7575757575757576, f_beta: 0.7692307692307692
# train: step: 104, loss: 0.651511013507843, acc: 0.6484375, recall: 0.5972222222222222, precision: 0.7288135593220338, f_beta: 0.6564885496183206
# train: step: 105, loss: 0.5329107046127319, acc: 0.7265625, recall: 0.6956521739130435, precision: 0.7741935483870968, f_beta: 0.732824427480916
# train: step: 106, loss: 0.5676642656326294, acc: 0.75, recall: 0.6973684210526315, precision: 0.8548387096774194, f_beta: 0.7681159420289855
# train: step: 107, loss: 0.6097545623779297, acc: 0.703125, recall: 0.7735849056603774, precision: 0.6119402985074627, f_beta: 0.6833333333333333
# train: step: 108, loss: 0.4963805377483368, acc: 0.7421875, recall: 0.8, precision: 0.6349206349206349, f_beta: 0.7079646017699115
# train: step: 109, loss: 0.6070150136947632, acc: 0.6640625, recall: 0.6901408450704225, precision: 0.7, f_beta: 0.6950354609929078
# train: step: 110, loss: 0.6618363857269287, acc: 0.65625, recall: 0.6764705882352942, precision: 0.6764705882352942, f_beta: 0.6764705882352942
# train: step: 111, loss: 0.5760409235954285, acc: 0.6953125, recall: 0.6933333333333334, precision: 0.7647058823529411, f_beta: 0.7272727272727272
# train: step: 112, loss: 0.5013066530227661, acc: 0.7421875, recall: 0.8095238095238095, precision: 0.7083333333333334, f_beta: 0.7555555555555556
# train: step: 113, loss: 0.5835411548614502, acc: 0.7265625, recall: 0.7936507936507936, precision: 0.6944444444444444, f_beta: 0.7407407407407406
# train: step: 114, loss: 0.48755884170532227, acc: 0.78125, recall: 0.8142857142857143, precision: 0.7916666666666666, f_beta: 0.8028169014084506
# train: step: 115, loss: 0.5358725786209106, acc: 0.7421875, recall: 0.8360655737704918, precision: 0.6891891891891891, f_beta: 0.7555555555555555
# train: step: 116, loss: 0.5381796360015869, acc: 0.6875, recall: 0.6545454545454545, precision: 0.631578947368421, f_beta: 0.6428571428571428
# train: step: 117, loss: 0.4765554666519165, acc: 0.7890625, recall: 0.7424242424242424, precision: 0.8305084745762712, f_beta: 0.784
# train: step: 118, loss: 0.5172358751296997, acc: 0.7734375, recall: 0.7, precision: 0.8596491228070176, f_beta: 0.7716535433070866
# train: step: 119, loss: 0.4521632790565491, acc: 0.7890625, recall: 0.7580645161290323, precision: 0.7966101694915254, f_beta: 0.7768595041322315
# train: step: 120, loss: 0.6275324821472168, acc: 0.734375, recall: 0.7647058823529411, precision: 0.7428571428571429, f_beta: 0.7536231884057971
# train: step: 121, loss: 0.4490429759025574, acc: 0.765625, recall: 0.7741935483870968, precision: 0.75, f_beta: 0.7619047619047619
# train: step: 122, loss: 0.48795533180236816, acc: 0.765625, recall: 0.7910447761194029, precision: 0.7681159420289855, f_beta: 0.7794117647058824
# train: step: 123, loss: 0.5513334274291992, acc: 0.7265625, recall: 0.7213114754098361, precision: 0.7096774193548387, f_beta: 0.7154471544715446
# train: step: 124, loss: 0.6085954904556274, acc: 0.734375, recall: 0.7936507936507936, precision: 0.704225352112676, f_beta: 0.7462686567164178
# train: step: 125, loss: 0.576694667339325, acc: 0.6796875, recall: 0.711864406779661, precision: 0.6363636363636364, f_beta: 0.672
# train: step: 126, loss: 0.48843446373939514, acc: 0.75, recall: 0.7945205479452054, precision: 0.7733333333333333, f_beta: 0.7837837837837838
# train: step: 127, loss: 0.5393401384353638, acc: 0.71875, recall: 0.6607142857142857, precision: 0.6851851851851852, f_beta: 0.6727272727272727
# train: step: 128, loss: 0.506340742111206, acc: 0.7734375, recall: 0.726027397260274, precision: 0.8548387096774194, f_beta: 0.7851851851851852
# train: step: 129, loss: 0.613309383392334, acc: 0.7421875, recall: 0.7076923076923077, precision: 0.7666666666666667, f_beta: 0.736
# train: step: 130, loss: 0.5239460468292236, acc: 0.7734375, recall: 0.8095238095238095, precision: 0.75, f_beta: 0.7786259541984734
# train: step: 131, loss: 0.5602264404296875, acc: 0.7421875, recall: 0.7692307692307693, precision: 0.7352941176470589, f_beta: 0.7518796992481205
# train: step: 132, loss: 0.5459011197090149, acc: 0.734375, recall: 0.7741935483870968, precision: 0.7058823529411765, f_beta: 0.7384615384615385
# train: step: 133, loss: 0.4470307528972626, acc: 0.78125, recall: 0.8301886792452831, precision: 0.6984126984126984, f_beta: 0.7586206896551724
# train: step: 134, loss: 0.49967074394226074, acc: 0.7734375, recall: 0.7741935483870968, precision: 0.7619047619047619, f_beta: 0.768
# train: step: 135, loss: 0.4658440351486206, acc: 0.7890625, recall: 0.75, precision: 0.8360655737704918, f_beta: 0.7906976744186046
# train: step: 136, loss: 0.5689080953598022, acc: 0.7109375, recall: 0.6557377049180327, precision: 0.7142857142857143, f_beta: 0.6837606837606838
# train: step: 137, loss: 0.42550283670425415, acc: 0.8125, recall: 0.8518518518518519, precision: 0.7419354838709677, f_beta: 0.7931034482758621
# train: step: 138, loss: 0.48461633920669556, acc: 0.7734375, recall: 0.8103448275862069, precision: 0.7230769230769231, f_beta: 0.7642276422764227
# train: step: 139, loss: 0.6041420698165894, acc: 0.703125, recall: 0.6842105263157895, precision: 0.6610169491525424, f_beta: 0.6724137931034484
# train: step: 140, loss: 0.446981817483902, acc: 0.7421875, recall: 0.6304347826086957, precision: 0.6444444444444445, f_beta: 0.6373626373626373
# train: step: 141, loss: 0.5510116219520569, acc: 0.75, recall: 0.6712328767123288, precision: 0.8596491228070176, f_beta: 0.7538461538461538
# train: step: 142, loss: 0.5200287103652954, acc: 0.6796875, recall: 0.5079365079365079, precision: 0.7619047619047619, f_beta: 0.6095238095238095
# train: step: 143, loss: 0.48126229643821716, acc: 0.7890625, recall: 0.7735849056603774, precision: 0.7321428571428571, f_beta: 0.7522935779816513
# train: step: 144, loss: 0.4768798351287842, acc: 0.8046875, recall: 0.7846153846153846, precision: 0.8225806451612904, f_beta: 0.8031496062992126
# train: step: 145, loss: 0.44774162769317627, acc: 0.7734375, recall: 0.8676470588235294, precision: 0.7468354430379747, f_beta: 0.8027210884353742
# train: step: 146, loss: 0.5397781729698181, acc: 0.75, recall: 0.9433962264150944, precision: 0.6329113924050633, f_beta: 0.7575757575757577
# train: step: 147, loss: 0.3875417709350586, acc: 0.828125, recall: 0.8405797101449275, precision: 0.8405797101449275, f_beta: 0.8405797101449275
# train: step: 148, loss: 0.4793604612350464, acc: 0.8046875, recall: 0.8181818181818182, precision: 0.75, f_beta: 0.7826086956521738
# train: step: 149, loss: 0.45557621121406555, acc: 0.7734375, recall: 0.7121212121212122, precision: 0.8245614035087719, f_beta: 0.7642276422764227
# train: step: 150, loss: 0.4640982747077942, acc: 0.78125, recall: 0.7213114754098361, precision: 0.8, f_beta: 0.7586206896551724
# train: step: 151, loss: 0.4137100577354431, acc: 0.8125, recall: 0.8070175438596491, precision: 0.7796610169491526, f_beta: 0.7931034482758621
# train: step: 152, loss: 0.45765379071235657, acc: 0.75, recall: 0.6984126984126984, precision: 0.7719298245614035, f_beta: 0.7333333333333333
# train: step: 153, loss: 0.47772330045700073, acc: 0.7421875, recall: 0.6833333333333333, precision: 0.7454545454545455, f_beta: 0.7130434782608696
# train: step: 154, loss: 0.4907677471637726, acc: 0.75, recall: 0.7313432835820896, precision: 0.7777777777777778, f_beta: 0.7538461538461538
# train: step: 155, loss: 0.5238326787948608, acc: 0.8125, recall: 0.8243243243243243, precision: 0.8472222222222222, f_beta: 0.8356164383561645
# train: step: 156, loss: 0.48145219683647156, acc: 0.7421875, recall: 0.7692307692307693, precision: 0.7352941176470589, f_beta: 0.7518796992481205
# start training model
# train: step: 157, loss: 0.39039018750190735, acc: 0.8203125, recall: 0.8787878787878788, precision: 0.7945205479452054, f_beta: 0.8345323741007193
# train: step: 158, loss: 0.3788186311721802, acc: 0.8359375, recall: 0.9041095890410958, precision: 0.825, f_beta: 0.8627450980392157
# train: step: 159, loss: 0.373723566532135, acc: 0.8203125, recall: 0.9333333333333333, precision: 0.7954545454545454, f_beta: 0.8588957055214724
# train: step: 160, loss: 0.42561399936676025, acc: 0.7890625, recall: 0.8904109589041096, precision: 0.7738095238095238, f_beta: 0.8280254777070064
# train: step: 161, loss: 0.4451206624507904, acc: 0.78125, recall: 0.8392857142857143, precision: 0.7121212121212122, f_beta: 0.7704918032786886
# train: step: 162, loss: 0.43315327167510986, acc: 0.8046875, recall: 0.7857142857142857, precision: 0.7719298245614035, f_beta: 0.7787610619469025
# train: step: 163, loss: 0.41577035188674927, acc: 0.796875, recall: 0.7285714285714285, precision: 0.8793103448275862, f_beta: 0.796875
# train: step: 164, loss: 0.4526248574256897, acc: 0.7578125, recall: 0.65625, precision: 0.8235294117647058, f_beta: 0.7304347826086957
# train: step: 165, loss: 0.44516634941101074, acc: 0.7890625, recall: 0.7166666666666667, precision: 0.8113207547169812, f_beta: 0.7610619469026548
# train: step: 166, loss: 0.3630284070968628, acc: 0.828125, recall: 0.75, precision: 0.84, f_beta: 0.7924528301886793
# train: step: 167, loss: 0.4061674475669861, acc: 0.828125, recall: 0.8253968253968254, precision: 0.8253968253968254, f_beta: 0.8253968253968254
# train: step: 168, loss: 0.38996005058288574, acc: 0.84375, recall: 0.9, precision: 0.7941176470588235, f_beta: 0.84375
# train: step: 169, loss: 0.45247185230255127, acc: 0.796875, recall: 0.8656716417910447, precision: 0.7733333333333333, f_beta: 0.8169014084507041
# train: step: 170, loss: 0.3879014849662781, acc: 0.828125, recall: 0.8360655737704918, precision: 0.8095238095238095, f_beta: 0.8225806451612904
# train: step: 171, loss: 0.2853296399116516, acc: 0.9140625, recall: 0.9459459459459459, precision: 0.9090909090909091, f_beta: 0.9271523178807948
# train: step: 172, loss: 0.3698779046535492, acc: 0.8046875, recall: 0.8833333333333333, precision: 0.7464788732394366, f_beta: 0.8091603053435115
# train: step: 173, loss: 0.3769831657409668, acc: 0.8359375, recall: 0.8095238095238095, precision: 0.85, f_beta: 0.8292682926829269
# train: step: 174, loss: 0.4152728021144867, acc: 0.8203125, recall: 0.8, precision: 0.8387096774193549, f_beta: 0.8188976377952757
# train: step: 175, loss: 0.4535466432571411, acc: 0.78125, recall: 0.6911764705882353, precision: 0.8703703703703703, f_beta: 0.7704918032786884
# train: step: 176, loss: 0.37308183312416077, acc: 0.84375, recall: 0.8714285714285714, precision: 0.8472222222222222, f_beta: 0.8591549295774648
# train: step: 177, loss: 0.4030953645706177, acc: 0.8203125, recall: 0.8666666666666667, precision: 0.7761194029850746, f_beta: 0.8188976377952756
# train: step: 178, loss: 0.45506933331489563, acc: 0.8125, recall: 0.8142857142857143, precision: 0.8382352941176471, f_beta: 0.8260869565217392
# train: step: 179, loss: 0.4809369444847107, acc: 0.796875, recall: 0.8591549295774648, precision: 0.7922077922077922, f_beta: 0.8243243243243243
# train: step: 180, loss: 0.4173513650894165, acc: 0.84375, recall: 0.896551724137931, precision: 0.7878787878787878, f_beta: 0.8387096774193549
# train: step: 181, loss: 0.3967845141887665, acc: 0.8203125, recall: 0.8676470588235294, precision: 0.8082191780821918, f_beta: 0.8368794326241135
# train: step: 182, loss: 0.40107765793800354, acc: 0.8515625, recall: 0.8923076923076924, precision: 0.8285714285714286, f_beta: 0.8592592592592593
# train: step: 183, loss: 0.36305323243141174, acc: 0.8515625, recall: 0.863013698630137, precision: 0.875, f_beta: 0.8689655172413793
# train: step: 184, loss: 0.33822983503341675, acc: 0.859375, recall: 0.835820895522388, precision: 0.8888888888888888, f_beta: 0.8615384615384615
# train: step: 185, loss: 0.3807736039161682, acc: 0.875, recall: 0.8421052631578947, precision: 0.8727272727272727, f_beta: 0.8571428571428571
# train: step: 186, loss: 0.4013950228691101, acc: 0.828125, recall: 0.8, precision: 0.875, f_beta: 0.8358208955223881
# train: step: 187, loss: 0.3324849605560303, acc: 0.828125, recall: 0.7857142857142857, precision: 0.8870967741935484, f_beta: 0.8333333333333333
# train: step: 188, loss: 0.3696666359901428, acc: 0.8203125, recall: 0.8225806451612904, precision: 0.8095238095238095, f_beta: 0.8160000000000001
# train: step: 189, loss: 0.40232396125793457, acc: 0.8046875, recall: 0.8382352941176471, precision: 0.8028169014084507, f_beta: 0.8201438848920864
# train: step: 190, loss: 0.32335183024406433, acc: 0.8203125, recall: 0.8823529411764706, precision: 0.8, f_beta: 0.8391608391608392
# train: step: 191, loss: 0.494235098361969, acc: 0.7734375, recall: 0.8571428571428571, precision: 0.7297297297297297, f_beta: 0.7883211678832117
# train: step: 192, loss: 0.4286930561065674, acc: 0.8515625, recall: 0.896551724137931, precision: 0.8, f_beta: 0.8455284552845529
# train: step: 193, loss: 0.38944509625434875, acc: 0.84375, recall: 0.890625, precision: 0.8142857142857143, f_beta: 0.8507462686567163
# train: step: 194, loss: 0.29728832840919495, acc: 0.859375, recall: 0.8214285714285714, precision: 0.8518518518518519, f_beta: 0.8363636363636364
# train: step: 195, loss: 0.40385082364082336, acc: 0.8203125, recall: 0.7358490566037735, precision: 0.8125, f_beta: 0.7722772277227722
# train: step: 196, loss: 0.3729248642921448, acc: 0.84375, recall: 0.75, precision: 0.9230769230769231, f_beta: 0.8275862068965517
# train: step: 197, loss: 0.4042763411998749, acc: 0.8359375, recall: 0.7681159420289855, precision: 0.9137931034482759, f_beta: 0.8346456692913387
# train: step: 198, loss: 0.38174131512641907, acc: 0.8203125, recall: 0.6833333333333333, precision: 0.9111111111111111, f_beta: 0.7809523809523808
# train: step: 199, loss: 0.44001954793930054, acc: 0.796875, recall: 0.7580645161290323, precision: 0.8103448275862069, f_beta: 0.7833333333333333
# train: step: 200, loss: 0.49676159024238586, acc: 0.7890625, recall: 0.8888888888888888, precision: 0.7368421052631579, f_beta: 0.8057553956834532
#
# Evaluation:
# 2019-07-26T14:05:18.706585, step: 200, loss: 0.392060847618641, acc: 0.8239182692307693,precision: 0.9116482899954779, recall: 0.7775012704564636, f_beta: 0.8384007844638283
# Saved model checkpoint to ../model/textCNN-200
#
# train: step: 201, loss: 0.595228910446167, acc: 0.7421875, recall: 0.9344262295081968, precision: 0.6627906976744186, f_beta: 0.7755102040816327
# train: step: 202, loss: 0.3149806261062622, acc: 0.90625, recall: 0.9846153846153847, precision: 0.8533333333333334, f_beta: 0.9142857142857143
# train: step: 203, loss: 0.353380024433136, acc: 0.875, recall: 0.8787878787878788, precision: 0.8787878787878788, f_beta: 0.8787878787878788
# train: step: 204, loss: 0.3316546082496643, acc: 0.8515625, recall: 0.8135593220338984, precision: 0.8571428571428571, f_beta: 0.8347826086956522
# train: step: 205, loss: 0.3570594787597656, acc: 0.8671875, recall: 0.8064516129032258, precision: 0.9090909090909091, f_beta: 0.8547008547008547
# train: step: 206, loss: 0.4183281660079956, acc: 0.8203125, recall: 0.7887323943661971, precision: 0.875, f_beta: 0.8296296296296297
# train: step: 207, loss: 0.4828004837036133, acc: 0.7890625, recall: 0.7903225806451613, precision: 0.7777777777777778, f_beta: 0.7839999999999999
# train: step: 208, loss: 0.26760590076446533, acc: 0.9140625, recall: 0.9473684210526315, precision: 0.8709677419354839, f_beta: 0.9075630252100839
# train: step: 209, loss: 0.4017978012561798, acc: 0.8203125, recall: 0.8, precision: 0.7857142857142857, f_beta: 0.7927927927927927
# train: step: 210, loss: 0.45914506912231445, acc: 0.7890625, recall: 0.7843137254901961, precision: 0.7142857142857143, f_beta: 0.7476635514018691
# train: step: 211, loss: 0.39492517709732056, acc: 0.8125, recall: 0.7796610169491526, precision: 0.8070175438596491, f_beta: 0.7931034482758621
# train: step: 212, loss: 0.4204605221748352, acc: 0.828125, recall: 0.8088235294117647, precision: 0.859375, f_beta: 0.8333333333333333
# train: step: 213, loss: 0.49661603569984436, acc: 0.796875, recall: 0.7540983606557377, precision: 0.8070175438596491, f_beta: 0.7796610169491526
# train: step: 214, loss: 0.4413169026374817, acc: 0.765625, recall: 0.7692307692307693, precision: 0.7692307692307693, f_beta: 0.7692307692307693
# train: step: 215, loss: 0.37932178378105164, acc: 0.84375, recall: 0.8732394366197183, precision: 0.8493150684931506, f_beta: 0.861111111111111
# train: step: 216, loss: 0.4691527187824249, acc: 0.765625, recall: 0.9, precision: 0.6923076923076923, f_beta: 0.7826086956521738
# train: step: 217, loss: 0.4739621877670288, acc: 0.8046875, recall: 0.8, precision: 0.8571428571428571, f_beta: 0.8275862068965518
# train: step: 218, loss: 0.35362082719802856, acc: 0.828125, recall: 0.8125, precision: 0.75, f_beta: 0.78
# train: step: 219, loss: 0.38118159770965576, acc: 0.796875, recall: 0.8235294117647058, precision: 0.8, f_beta: 0.8115942028985507
# train: step: 220, loss: 0.42012351751327515, acc: 0.8046875, recall: 0.8208955223880597, precision: 0.8088235294117647, f_beta: 0.8148148148148148
# train: step: 221, loss: 0.3582814335823059, acc: 0.8359375, recall: 0.8412698412698413, precision: 0.828125, f_beta: 0.8346456692913385
# train: step: 222, loss: 0.4405363202095032, acc: 0.828125, recall: 0.78125, precision: 0.8620689655172413, f_beta: 0.8196721311475409
# train: step: 223, loss: 0.29562562704086304, acc: 0.8828125, recall: 0.8412698412698413, precision: 0.9137931034482759, f_beta: 0.8760330578512397
# train: step: 224, loss: 0.34189775586128235, acc: 0.8515625, recall: 0.8947368421052632, precision: 0.796875, f_beta: 0.8429752066115702
# train: step: 225, loss: 0.4569784998893738, acc: 0.7734375, recall: 0.8142857142857143, precision: 0.7808219178082192, f_beta: 0.7972027972027972
# train: step: 226, loss: 0.32263514399528503, acc: 0.875, recall: 0.8939393939393939, precision: 0.8676470588235294, f_beta: 0.8805970149253731
# train: step: 227, loss: 0.3746437132358551, acc: 0.8671875, recall: 0.8688524590163934, precision: 0.8548387096774194, f_beta: 0.8617886178861789
# train: step: 228, loss: 0.33550047874450684, acc: 0.8359375, recall: 0.8653846153846154, precision: 0.7627118644067796, f_beta: 0.8108108108108109
# train: step: 229, loss: 0.3771621584892273, acc: 0.828125, recall: 0.8833333333333333, precision: 0.7794117647058824, f_beta: 0.8281250000000001
# train: step: 230, loss: 0.3577260375022888, acc: 0.8515625, recall: 0.9454545454545454, precision: 0.7647058823529411, f_beta: 0.8455284552845528
# train: step: 231, loss: 0.3900259733200073, acc: 0.828125, recall: 0.810126582278481, precision: 0.9014084507042254, f_beta: 0.8533333333333334
# train: step: 232, loss: 0.40743377804756165, acc: 0.828125, recall: 0.8918918918918919, precision: 0.825, f_beta: 0.8571428571428571
# train: step: 233, loss: 0.48875099420547485, acc: 0.765625, recall: 0.7333333333333333, precision: 0.8461538461538461, f_beta: 0.7857142857142856
# train: step: 234, loss: 0.38135233521461487, acc: 0.8515625, recall: 0.8970588235294118, precision: 0.8356164383561644, f_beta: 0.8652482269503545
# train: step: 235, loss: 0.41840097308158875, acc: 0.8046875, recall: 0.8181818181818182, precision: 0.75, f_beta: 0.7826086956521738
# train: step: 236, loss: 0.44924530386924744, acc: 0.84375, recall: 0.9130434782608695, precision: 0.8181818181818182, f_beta: 0.863013698630137
# train: step: 237, loss: 0.27242574095726013, acc: 0.8984375, recall: 0.9285714285714286, precision: 0.8904109589041096, f_beta: 0.9090909090909091
# train: step: 238, loss: 0.47711288928985596, acc: 0.75, recall: 0.8103448275862069, precision: 0.6911764705882353, f_beta: 0.746031746031746
# train: step: 239, loss: 0.44424647092819214, acc: 0.765625, recall: 0.746031746031746, precision: 0.7704918032786885, f_beta: 0.7580645161290323
# train: step: 240, loss: 0.5081570744514465, acc: 0.78125, recall: 0.7272727272727273, precision: 0.8275862068965517, f_beta: 0.7741935483870968
# train: step: 241, loss: 0.38144761323928833, acc: 0.8359375, recall: 0.8153846153846154, precision: 0.8548387096774194, f_beta: 0.8346456692913387
# train: step: 242, loss: 0.35580599308013916, acc: 0.8359375, recall: 0.7966101694915254, precision: 0.8392857142857143, f_beta: 0.8173913043478261
# train: step: 243, loss: 0.3538041412830353, acc: 0.828125, recall: 0.8142857142857143, precision: 0.8636363636363636, f_beta: 0.8382352941176471
# train: step: 244, loss: 0.30118125677108765, acc: 0.875, recall: 0.9193548387096774, precision: 0.8382352941176471, f_beta: 0.8769230769230769
# train: step: 245, loss: 0.2790381908416748, acc: 0.875, recall: 0.873015873015873, precision: 0.873015873015873, f_beta: 0.8730158730158731
# train: step: 246, loss: 0.4129788875579834, acc: 0.8125, recall: 0.8833333333333333, precision: 0.7571428571428571, f_beta: 0.8153846153846154
# train: step: 247, loss: 0.25185465812683105, acc: 0.890625, recall: 0.9420289855072463, precision: 0.8666666666666667, f_beta: 0.9027777777777778
# train: step: 248, loss: 0.34904029965400696, acc: 0.8203125, recall: 0.8055555555555556, precision: 0.8656716417910447, f_beta: 0.8345323741007193
# train: step: 249, loss: 0.441644549369812, acc: 0.8515625, recall: 0.8461538461538461, precision: 0.859375, f_beta: 0.8527131782945736
# train: step: 250, loss: 0.2904165983200073, acc: 0.8515625, recall: 0.8923076923076924, precision: 0.8285714285714286, f_beta: 0.8592592592592593
# train: step: 251, loss: 0.3502175807952881, acc: 0.8046875, recall: 0.8076923076923077, precision: 0.863013698630137, f_beta: 0.8344370860927152
# train: step: 252, loss: 0.36749476194381714, acc: 0.8828125, recall: 0.9393939393939394, precision: 0.8493150684931506, f_beta: 0.8920863309352518
# train: step: 253, loss: 0.3660951256752014, acc: 0.8671875, recall: 0.9047619047619048, precision: 0.8382352941176471, f_beta: 0.8702290076335878
# train: step: 254, loss: 0.48233547806739807, acc: 0.7578125, recall: 0.8571428571428571, precision: 0.6363636363636364, f_beta: 0.7304347826086957
# train: step: 255, loss: 0.2932989299297333, acc: 0.9140625, recall: 0.8902439024390244, precision: 0.9733333333333334, f_beta: 0.9299363057324841
# train: step: 256, loss: 0.4087717831134796, acc: 0.8046875, recall: 0.8059701492537313, precision: 0.8181818181818182, f_beta: 0.8120300751879699
# train: step: 257, loss: 0.41276460886001587, acc: 0.828125, recall: 0.8095238095238095, precision: 0.8360655737704918, f_beta: 0.8225806451612904
# train: step: 258, loss: 0.25544703006744385, acc: 0.859375, recall: 0.8461538461538461, precision: 0.873015873015873, f_beta: 0.859375
# train: step: 259, loss: 0.3629799485206604, acc: 0.8203125, recall: 0.8833333333333333, precision: 0.7681159420289855, f_beta: 0.8217054263565893
# train: step: 260, loss: 0.3745464086532593, acc: 0.84375, recall: 0.8285714285714286, precision: 0.8787878787878788, f_beta: 0.8529411764705883
# train: step: 261, loss: 0.39257535338401794, acc: 0.8203125, recall: 0.7538461538461538, precision: 0.875, f_beta: 0.8099173553719008
# train: step: 262, loss: 0.4100434482097626, acc: 0.8359375, recall: 0.9354838709677419, precision: 0.7733333333333333, f_beta: 0.8467153284671532
# train: step: 263, loss: 0.28843286633491516, acc: 0.875, recall: 0.8955223880597015, precision: 0.8695652173913043, f_beta: 0.8823529411764706
# train: step: 264, loss: 0.3374449610710144, acc: 0.875, recall: 0.9178082191780822, precision: 0.8701298701298701, f_beta: 0.8933333333333333
# train: step: 265, loss: 0.30892878770828247, acc: 0.859375, recall: 0.9454545454545454, precision: 0.7761194029850746, f_beta: 0.8524590163934428
# train: step: 266, loss: 0.3849238157272339, acc: 0.828125, recall: 0.7704918032786885, precision: 0.8545454545454545, f_beta: 0.810344827586207
# train: step: 267, loss: 0.3120271563529968, acc: 0.8359375, recall: 0.8095238095238095, precision: 0.85, f_beta: 0.8292682926829269
# train: step: 268, loss: 0.3661532998085022, acc: 0.84375, recall: 0.803030303030303, precision: 0.8833333333333333, f_beta: 0.8412698412698413
# train: step: 269, loss: 0.3531401455402374, acc: 0.8671875, recall: 0.9056603773584906, precision: 0.8, f_beta: 0.8495575221238938
# train: step: 270, loss: 0.3989327549934387, acc: 0.828125, recall: 0.803030303030303, precision: 0.8548387096774194, f_beta: 0.828125
# train: step: 271, loss: 0.4343598783016205, acc: 0.7734375, recall: 0.7580645161290323, precision: 0.7704918032786885, f_beta: 0.7642276422764228
# train: step: 272, loss: 0.447487473487854, acc: 0.8046875, recall: 0.7758620689655172, precision: 0.7894736842105263, f_beta: 0.7826086956521741
# train: step: 273, loss: 0.3627905249595642, acc: 0.8125, recall: 0.765625, precision: 0.8448275862068966, f_beta: 0.8032786885245901
# train: step: 274, loss: 0.36149337887763977, acc: 0.8515625, recall: 0.8771929824561403, precision: 0.8064516129032258, f_beta: 0.8403361344537815
# train: step: 275, loss: 0.29115042090415955, acc: 0.8828125, recall: 0.8833333333333333, precision: 0.8688524590163934, f_beta: 0.8760330578512396
# train: step: 276, loss: 0.4244508147239685, acc: 0.828125, recall: 0.8620689655172413, precision: 0.78125, f_beta: 0.8196721311475409
# train: step: 277, loss: 0.36772620677948, acc: 0.8359375, recall: 0.847457627118644, precision: 0.8064516129032258, f_beta: 0.8264462809917354
# train: step: 278, loss: 0.2862687408924103, acc: 0.875, recall: 0.9032258064516129, precision: 0.8484848484848485, f_beta: 0.875
# train: step: 279, loss: 0.39659857749938965, acc: 0.8359375, recall: 0.8529411764705882, precision: 0.8405797101449275, f_beta: 0.8467153284671534
# train: step: 280, loss: 0.4419020116329193, acc: 0.8203125, recall: 0.7301587301587301, precision: 0.8846153846153846, f_beta: 0.7999999999999999
# train: step: 281, loss: 0.43868932127952576, acc: 0.7890625, recall: 0.7575757575757576, precision: 0.819672131147541, f_beta: 0.7874015748031497
# train: step: 282, loss: 0.36560168862342834, acc: 0.84375, recall: 0.9454545454545454, precision: 0.7536231884057971, f_beta: 0.8387096774193549
# train: step: 283, loss: 0.39744994044303894, acc: 0.828125, recall: 0.8260869565217391, precision: 0.8507462686567164, f_beta: 0.838235294117647
# train: step: 284, loss: 0.4403947591781616, acc: 0.7890625, recall: 0.8148148148148148, precision: 0.7213114754098361, f_beta: 0.7652173913043478
# train: step: 285, loss: 0.4224989712238312, acc: 0.8203125, recall: 0.875, precision: 0.7538461538461538, f_beta: 0.8099173553719008
# train: step: 286, loss: 0.4177049398422241, acc: 0.8046875, recall: 0.847457627118644, precision: 0.7575757575757576, f_beta: 0.7999999999999999
# train: step: 287, loss: 0.3757634162902832, acc: 0.8671875, recall: 0.803030303030303, precision: 0.9298245614035088, f_beta: 0.8617886178861788
# train: step: 288, loss: 0.3453071713447571, acc: 0.84375, recall: 0.8253968253968254, precision: 0.8524590163934426, f_beta: 0.8387096774193549
# train: step: 289, loss: 0.34428027272224426, acc: 0.8125, recall: 0.7794117647058824, precision: 0.8548387096774194, f_beta: 0.8153846153846154
# train: step: 290, loss: 0.3005201518535614, acc: 0.890625, recall: 0.9016393442622951, precision: 0.873015873015873, f_beta: 0.8870967741935485
# train: step: 291, loss: 0.3752177357673645, acc: 0.8515625, recall: 0.75, precision: 0.8936170212765957, f_beta: 0.8155339805825244
# train: step: 292, loss: 0.3830568194389343, acc: 0.828125, recall: 0.8405797101449275, precision: 0.8405797101449275, f_beta: 0.8405797101449275
# train: step: 293, loss: 0.44956162571907043, acc: 0.8125, recall: 0.8852459016393442, precision: 0.7605633802816901, f_beta: 0.8181818181818182
# train: step: 294, loss: 0.2633017301559448, acc: 0.875, recall: 0.9047619047619048, precision: 0.8507462686567164, f_beta: 0.8769230769230769
# train: step: 295, loss: 0.29562124609947205, acc: 0.875, recall: 0.8852459016393442, precision: 0.8571428571428571, f_beta: 0.8709677419354839
# train: step: 296, loss: 0.3987821936607361, acc: 0.8125, recall: 0.9122807017543859, precision: 0.7323943661971831, f_beta: 0.8124999999999999
# train: step: 297, loss: 0.40164846181869507, acc: 0.8203125, recall: 0.7910447761194029, precision: 0.8548387096774194, f_beta: 0.8217054263565892
# train: step: 298, loss: 0.3028238117694855, acc: 0.8671875, recall: 0.873015873015873, precision: 0.859375, f_beta: 0.8661417322834646
# train: step: 299, loss: 0.362740159034729, acc: 0.8046875, recall: 0.7532467532467533, precision: 0.90625, f_beta: 0.822695035460993
# train: step: 300, loss: 0.4306216239929199, acc: 0.8125, recall: 0.7714285714285715, precision: 0.8709677419354839, f_beta: 0.8181818181818182
#
# Evaluation:
# 2019-07-26T14:05:51.216660, step: 300, loss: 0.34421566357979405, acc: 0.8513621794871795,precision: 0.8856249324947502, recall: 0.8322719180621354, f_beta: 0.856750714997741
# Saved model checkpoint to ../model/textCNN-300
#
# train: step: 301, loss: 0.38953712582588196, acc: 0.828125, recall: 0.8392857142857143, precision: 0.7833333333333333, f_beta: 0.8103448275862069
# train: step: 302, loss: 0.29230645298957825, acc: 0.859375, recall: 0.9285714285714286, precision: 0.8333333333333334, f_beta: 0.8783783783783784
# train: step: 303, loss: 0.2875002920627594, acc: 0.875, recall: 0.8235294117647058, precision: 0.8571428571428571, f_beta: 0.84
# train: step: 304, loss: 0.3951851427555084, acc: 0.8359375, recall: 0.9310344827586207, precision: 0.7605633802816901, f_beta: 0.8372093023255814
# train: step: 305, loss: 0.3753577470779419, acc: 0.8359375, recall: 0.8360655737704918, precision: 0.8225806451612904, f_beta: 0.829268292682927
# train: step: 306, loss: 0.3154922127723694, acc: 0.875, recall: 0.9523809523809523, precision: 0.821917808219178, f_beta: 0.8823529411764706
# train: step: 307, loss: 0.45091551542282104, acc: 0.8359375, recall: 0.868421052631579, precision: 0.8571428571428571, f_beta: 0.8627450980392157
# train: step: 308, loss: 0.36394983530044556, acc: 0.84375, recall: 0.8166666666666667, precision: 0.8448275862068966, f_beta: 0.8305084745762712
# train: step: 309, loss: 0.37519222497940063, acc: 0.828125, recall: 0.7611940298507462, precision: 0.8947368421052632, f_beta: 0.8225806451612904
# train: step: 310, loss: 0.3264022171497345, acc: 0.8671875, recall: 0.8032786885245902, precision: 0.9074074074074074, f_beta: 0.8521739130434782
# train: step: 311, loss: 0.34451940655708313, acc: 0.828125, recall: 0.828125, precision: 0.828125, f_beta: 0.828125
# train: step: 312, loss: 0.35775914788246155, acc: 0.84375, recall: 0.8714285714285714, precision: 0.8472222222222222, f_beta: 0.8591549295774648
# start training model
# train: step: 313, loss: 0.3297629952430725, acc: 0.8359375, recall: 0.9259259259259259, precision: 0.746268656716418, f_beta: 0.8264462809917356
# train: step: 314, loss: 0.306605726480484, acc: 0.859375, recall: 0.8870967741935484, precision: 0.8333333333333334, f_beta: 0.859375
# train: step: 315, loss: 0.30269795656204224, acc: 0.859375, recall: 0.896551724137931, precision: 0.8125, f_beta: 0.8524590163934426
# train: step: 316, loss: 0.3261317312717438, acc: 0.8515625, recall: 0.8571428571428571, precision: 0.8695652173913043, f_beta: 0.8633093525179856
# train: step: 317, loss: 0.2479417622089386, acc: 0.90625, recall: 0.8833333333333333, precision: 0.9137931034482759, f_beta: 0.8983050847457628
# train: step: 318, loss: 0.30090540647506714, acc: 0.8671875, recall: 0.85, precision: 0.864406779661017, f_beta: 0.8571428571428572
# train: step: 319, loss: 0.30036693811416626, acc: 0.8828125, recall: 0.8771929824561403, precision: 0.8620689655172413, f_beta: 0.8695652173913043
# train: step: 320, loss: 0.2828231751918793, acc: 0.859375, recall: 0.8148148148148148, precision: 0.8461538461538461, f_beta: 0.830188679245283
# train: step: 321, loss: 0.3257337212562561, acc: 0.8515625, recall: 0.7702702702702703, precision: 0.9661016949152542, f_beta: 0.8571428571428571
# train: step: 322, loss: 0.28787821531295776, acc: 0.875, recall: 0.8529411764705882, precision: 0.90625, f_beta: 0.8787878787878787
# train: step: 323, loss: 0.3230797052383423, acc: 0.8515625, recall: 0.8636363636363636, precision: 0.8507462686567164, f_beta: 0.8571428571428571
# train: step: 324, loss: 0.2769441306591034, acc: 0.8984375, recall: 0.9344262295081968, precision: 0.8636363636363636, f_beta: 0.8976377952755905
# train: step: 325, loss: 0.3469036817550659, acc: 0.8671875, recall: 0.9558823529411765, precision: 0.8227848101265823, f_beta: 0.8843537414965986
# train: step: 326, loss: 0.328607439994812, acc: 0.859375, recall: 0.9523809523809523, precision: 0.8, f_beta: 0.8695652173913043
# ...
# train: step: 675, loss: 0.17884480953216553, acc: 0.9375, recall: 0.96875, precision: 0.9117647058823529, f_beta: 0.9393939393939394
# train: step: 676, loss: 0.14333395659923553, acc: 0.96875, recall: 0.967741935483871, precision: 0.967741935483871, f_beta: 0.967741935483871
# train: step: 677, loss: 0.12649916112422943, acc: 0.9765625, recall: 0.9841269841269841, precision: 0.96875, f_beta: 0.9763779527559054
# train: step: 678, loss: 0.1053987443447113, acc: 0.9609375, recall: 0.9661016949152542, precision: 0.95, f_beta: 0.957983193277311
# train: step: 679, loss: 0.18550604581832886, acc: 0.953125, recall: 0.9571428571428572, precision: 0.9571428571428572, f_beta: 0.9571428571428572
# train: step: 680, loss: 0.18822689354419708, acc: 0.9453125, recall: 0.9178082191780822, precision: 0.9852941176470589, f_beta: 0.9503546099290779
# train: step: 681, loss: 0.1288607120513916, acc: 0.9609375, recall: 0.9545454545454546, precision: 0.9692307692307692, f_beta: 0.9618320610687022
# train: step: 682, loss: 0.1502799093723297, acc: 0.953125, recall: 0.9577464788732394, precision: 0.9577464788732394, f_beta: 0.9577464788732394
# train: step: 683, loss: 0.13513264060020447, acc: 0.96875, recall: 0.9838709677419355, precision: 0.953125, f_beta: 0.9682539682539683
# train: step: 684, loss: 0.1629887819290161, acc: 0.953125, recall: 0.9814814814814815, precision: 0.9137931034482759, f_beta: 0.9464285714285714
# train: step: 685, loss: 0.16331441700458527, acc: 0.9296875, recall: 0.9016393442622951, precision: 0.9482758620689655, f_beta: 0.9243697478991596
# train: step: 686, loss: 0.15291933715343475, acc: 0.9453125, recall: 0.9482758620689655, precision: 0.9322033898305084, f_beta: 0.94017094017094
# train: step: 687, loss: 0.15389196574687958, acc: 0.9453125, recall: 0.921875, precision: 0.9672131147540983, f_beta: 0.944
# train: step: 688, loss: 0.15351559221744537, acc: 0.9375, recall: 0.9130434782608695, precision: 0.9692307692307692, f_beta: 0.9402985074626865
# train: step: 689, loss: 0.1387317180633545, acc: 0.9609375, recall: 0.967741935483871, precision: 0.9523809523809523, f_beta: 0.96
# train: step: 690, loss: 0.12060791999101639, acc: 0.9609375, recall: 0.96875, precision: 0.9538461538461539, f_beta: 0.9612403100775193
# train: step: 691, loss: 0.12281215190887451, acc: 0.96875, recall: 0.9464285714285714, precision: 0.9814814814814815, f_beta: 0.9636363636363636
# train: step: 692, loss: 0.1666562259197235, acc: 0.9375, recall: 0.9016393442622951, precision: 0.9649122807017544, f_beta: 0.9322033898305084
# train: step: 693, loss: 0.15729588270187378, acc: 0.953125, recall: 0.953125, precision: 0.953125, f_beta: 0.953125
# train: step: 694, loss: 0.12334945052862167, acc: 0.96875, recall: 0.9436619718309859, precision: 1.0, f_beta: 0.9710144927536231
# train: step: 695, loss: 0.11654557287693024, acc: 0.96875, recall: 0.967741935483871, precision: 0.967741935483871, f_beta: 0.967741935483871
# train: step: 696, loss: 0.13598212599754333, acc: 0.96875, recall: 0.974025974025974, precision: 0.974025974025974, f_beta: 0.974025974025974
# train: step: 697, loss: 0.14847730100154877, acc: 0.953125, recall: 0.9714285714285714, precision: 0.9444444444444444, f_beta: 0.9577464788732395
# train: step: 698, loss: 0.16081945598125458, acc: 0.953125, recall: 0.9861111111111112, precision: 0.9342105263157895, f_beta: 0.9594594594594595
# train: step: 699, loss: 0.1625438630580902, acc: 0.9453125, recall: 1.0, precision: 0.8939393939393939, f_beta: 0.944
# train: step: 700, loss: 0.14502888917922974, acc: 0.9453125, recall: 0.9206349206349206, precision: 0.9666666666666667, f_beta: 0.943089430894309
#
# Evaluation:
# 2019-07-26T14:07:58.027672, step: 700, loss: 0.3210926480018176, acc: 0.8651842948717948,precision: 0.87111699487164, recall: 0.8643398565972495, f_beta: 0.8665200845522841
# Saved model checkpoint to ../model/textCNN-700
#
# train: step: 701, loss: 0.14260521531105042, acc: 0.9375, recall: 0.9393939393939394, precision: 0.9393939393939394, f_beta: 0.9393939393939394
# train: step: 702, loss: 0.13976991176605225, acc: 0.953125, recall: 0.9230769230769231, precision: 0.96, f_beta: 0.9411764705882353
# train: step: 703, loss: 0.11140862107276917, acc: 0.9765625, recall: 0.9508196721311475, precision: 1.0, f_beta: 0.9747899159663865
# train: step: 704, loss: 0.17667022347450256, acc: 0.953125, recall: 0.9464285714285714, precision: 0.9464285714285714, f_beta: 0.9464285714285714
# train: step: 705, loss: 0.11424538493156433, acc: 0.96875, recall: 0.9558823529411765, precision: 0.9848484848484849, f_beta: 0.9701492537313432
# train: step: 706, loss: 0.11761756241321564, acc: 0.9765625, recall: 0.9655172413793104, precision: 0.9824561403508771, f_beta: 0.9739130434782608
# train: step: 707, loss: 0.1713993400335312, acc: 0.953125, recall: 0.9491525423728814, precision: 0.9491525423728814, f_beta: 0.9491525423728814
# train: step: 708, loss: 0.1305314004421234, acc: 0.9609375, recall: 0.9375, precision: 0.9836065573770492, f_beta: 0.96
# train: step: 709, loss: 0.153171569108963, acc: 0.9453125, recall: 0.9846153846153847, precision: 0.9142857142857143, f_beta: 0.9481481481481482
# train: step: 710, loss: 0.19008800387382507, acc: 0.9296875, recall: 0.9666666666666667, precision: 0.8923076923076924, f_beta: 0.928
# train: step: 711, loss: 0.1129080206155777, acc: 0.96875, recall: 0.9672131147540983, precision: 0.9672131147540983, f_beta: 0.9672131147540983
# train: step: 712, loss: 0.18774858117103577, acc: 0.9296875, recall: 0.9193548387096774, precision: 0.9344262295081968, f_beta: 0.9268292682926829
# train: step: 713, loss: 0.12901648879051208, acc: 0.96875, recall: 0.9428571428571428, precision: 1.0, f_beta: 0.9705882352941176
# train: step: 714, loss: 0.17494404315948486, acc: 0.9453125, recall: 0.9508196721311475, precision: 0.9354838709677419, f_beta: 0.943089430894309
# train: step: 715, loss: 0.12893709540367126, acc: 0.953125, recall: 0.9545454545454546, precision: 0.9545454545454546, f_beta: 0.9545454545454546
# train: step: 716, loss: 0.16032053530216217, acc: 0.9296875, recall: 0.9230769230769231, precision: 0.9375, f_beta: 0.9302325581395349
# train: step: 717, loss: 0.1466818004846573, acc: 0.9453125, recall: 0.9846153846153847, precision: 0.9142857142857143, f_beta: 0.9481481481481482
# train: step: 718, loss: 0.15627935528755188, acc: 0.9453125, recall: 0.9393939393939394, precision: 0.9538461538461539, f_beta: 0.9465648854961831
# train: step: 719, loss: 0.19274261593818665, acc: 0.9140625, recall: 0.8970588235294118, precision: 0.9384615384615385, f_beta: 0.9172932330827067
# train: step: 720, loss: 0.1222994327545166, acc: 0.9765625, recall: 0.9846153846153847, precision: 0.9696969696969697, f_beta: 0.9770992366412214
# train: step: 721, loss: 0.2129334807395935, acc: 0.9453125, recall: 0.9827586206896551, precision: 0.9047619047619048, f_beta: 0.9421487603305785
# train: step: 722, loss: 0.1384192258119583, acc: 0.953125, recall: 0.9692307692307692, precision: 0.9402985074626866, f_beta: 0.9545454545454547
# train: step: 723, loss: 0.18366992473602295, acc: 0.9296875, recall: 0.9491525423728814, precision: 0.9032258064516129, f_beta: 0.9256198347107438
# train: step: 724, loss: 0.12798434495925903, acc: 0.96875, recall: 0.9642857142857143, precision: 0.9642857142857143, f_beta: 0.9642857142857143
# train: step: 725, loss: 0.15477004647254944, acc: 0.9296875, recall: 0.9117647058823529, precision: 0.9538461538461539, f_beta: 0.9323308270676691
# train: step: 726, loss: 0.15970036387443542, acc: 0.953125, recall: 0.9322033898305084, precision: 0.9649122807017544, f_beta: 0.9482758620689654
# train: step: 727, loss: 0.17529118061065674, acc: 0.921875, recall: 0.8787878787878788, precision: 0.9666666666666667, f_beta: 0.9206349206349207
# train: step: 728, loss: 0.1799980103969574, acc: 0.9609375, recall: 0.9523809523809523, precision: 0.967741935483871, f_beta: 0.96
# train: step: 729, loss: 0.10178367793560028, acc: 0.9765625, recall: 0.9701492537313433, precision: 0.9848484848484849, f_beta: 0.9774436090225564
# train: step: 730, loss: 0.2236587405204773, acc: 0.9375, recall: 0.9565217391304348, precision: 0.9295774647887324, f_beta: 0.9428571428571428
# train: step: 731, loss: 0.2202022671699524, acc: 0.90625, recall: 0.921875, precision: 0.8939393939393939, f_beta: 0.9076923076923077
# train: step: 732, loss: 0.12455233931541443, acc: 0.96875, recall: 0.984375, precision: 0.9545454545454546, f_beta: 0.9692307692307692
# train: step: 733, loss: 0.17145052552223206, acc: 0.9140625, recall: 0.9393939393939394, precision: 0.8985507246376812, f_beta: 0.9185185185185185
# train: step: 734, loss: 0.10754053294658661, acc: 0.9765625, recall: 0.9838709677419355, precision: 0.9682539682539683, f_beta: 0.976
# train: step: 735, loss: 0.1145046055316925, acc: 0.953125, recall: 0.9464285714285714, precision: 0.9464285714285714, f_beta: 0.9464285714285714
# train: step: 736, loss: 0.2669329047203064, acc: 0.90625, recall: 0.9, precision: 0.9264705882352942, f_beta: 0.9130434782608695
# train: step: 737, loss: 0.17163296043872833, acc: 0.96875, recall: 0.9516129032258065, precision: 0.9833333333333333, f_beta: 0.9672131147540983
# train: step: 738, loss: 0.15914152562618256, acc: 0.9296875, recall: 0.8787878787878788, precision: 0.9830508474576272, f_beta: 0.9279999999999999
# train: step: 739, loss: 0.12331485748291016, acc: 0.953125, recall: 0.9253731343283582, precision: 0.9841269841269841, f_beta: 0.9538461538461538
# train: step: 740, loss: 0.13674187660217285, acc: 0.953125, recall: 0.9384615384615385, precision: 0.9682539682539683, f_beta: 0.953125
# train: step: 741, loss: 0.2089436948299408, acc: 0.890625, recall: 0.9852941176470589, precision: 0.8375, f_beta: 0.9054054054054055
# train: step: 742, loss: 0.21493341028690338, acc: 0.9296875, recall: 1.0, precision: 0.8714285714285714, f_beta: 0.9312977099236641
# train: step: 743, loss: 0.11450269818305969, acc: 0.953125, recall: 0.9833333333333333, precision: 0.921875, f_beta: 0.9516129032258064
# train: step: 744, loss: 0.1712646484375, acc: 0.9375, recall: 0.9375, precision: 0.9375, f_beta: 0.9375
# train: step: 745, loss: 0.19495975971221924, acc: 0.921875, recall: 0.8870967741935484, precision: 0.9482758620689655, f_beta: 0.9166666666666667
# train: step: 746, loss: 0.20973405241966248, acc: 0.9296875, recall: 0.8870967741935484, precision: 0.9649122807017544, f_beta: 0.9243697478991597
# train: step: 747, loss: 0.19522450864315033, acc: 0.921875, recall: 0.8548387096774194, precision: 0.9814814814814815, f_beta: 0.9137931034482759
# train: step: 748, loss: 0.17463253438472748, acc: 0.953125, recall: 0.9682539682539683, precision: 0.9384615384615385, f_beta: 0.953125
# train: step: 749, loss: 0.13993903994560242, acc: 0.953125, recall: 0.9655172413793104, precision: 0.9333333333333333, f_beta: 0.9491525423728815
# train: step: 750, loss: 0.1257757544517517, acc: 0.9609375, recall: 1.0, precision: 0.927536231884058, f_beta: 0.9624060150375939
# train: step: 751, loss: 0.11408533155918121, acc: 0.984375, recall: 0.9827586206896551, precision: 0.9827586206896551, f_beta: 0.9827586206896551
# train: step: 752, loss: 0.15110242366790771, acc: 0.9375, recall: 0.9264705882352942, precision: 0.9545454545454546, f_beta: 0.9402985074626866
# train: step: 753, loss: 0.13787218928337097, acc: 0.9765625, recall: 0.9846153846153847, precision: 0.9696969696969697, f_beta: 0.9770992366412214
# train: step: 754, loss: 0.1175433099269867, acc: 0.953125, recall: 0.9315068493150684, precision: 0.9855072463768116, f_beta: 0.9577464788732394
# train: step: 755, loss: 0.18936321139335632, acc: 0.921875, recall: 0.918918918918919, precision: 0.9444444444444444, f_beta: 0.9315068493150684
# train: step: 756, loss: 0.13136222958564758, acc: 0.96875, recall: 0.9852941176470589, precision: 0.9571428571428572, f_beta: 0.9710144927536232
# train: step: 757, loss: 0.13498874008655548, acc: 0.9609375, recall: 0.9482758620689655, precision: 0.9649122807017544, f_beta: 0.9565217391304347
# train: step: 758, loss: 0.19169697165489197, acc: 0.90625, recall: 0.9508196721311475, precision: 0.8656716417910447, f_beta: 0.9062499999999999
# train: step: 759, loss: 0.1958613097667694, acc: 0.9453125, recall: 0.9558823529411765, precision: 0.9420289855072463, f_beta: 0.9489051094890512
# train: step: 760, loss: 0.11925399303436279, acc: 0.96875, recall: 0.9523809523809523, precision: 0.9836065573770492, f_beta: 0.9677419354838709
# train: step: 761, loss: 0.20413747429847717, acc: 0.953125, recall: 0.9464285714285714, precision: 0.9464285714285714, f_beta: 0.9464285714285714
# train: step: 762, loss: 0.11446474492549896, acc: 0.9765625, recall: 0.9833333333333333, precision: 0.9672131147540983, f_beta: 0.9752066115702478
# train: step: 763, loss: 0.12251163274049759, acc: 0.9609375, recall: 0.9473684210526315, precision: 0.9863013698630136, f_beta: 0.9664429530201343
# train: step: 764, loss: 0.16526608169078827, acc: 0.9453125, recall: 0.9365079365079365, precision: 0.9516129032258065, f_beta: 0.944
# train: step: 765, loss: 0.14595162868499756, acc: 0.953125, recall: 0.9482758620689655, precision: 0.9482758620689655, f_beta: 0.9482758620689655
# train: step: 766, loss: 0.13505278527736664, acc: 0.9453125, recall: 0.9508196721311475, precision: 0.9354838709677419, f_beta: 0.943089430894309
# train: step: 767, loss: 0.13351115584373474, acc: 0.9609375, recall: 0.9863013698630136, precision: 0.9473684210526315, f_beta: 0.9664429530201343
# train: step: 768, loss: 0.1576523780822754, acc: 0.9296875, recall: 0.9833333333333333, precision: 0.8805970149253731, f_beta: 0.9291338582677166
# train: step: 769, loss: 0.16547876596450806, acc: 0.9375, recall: 0.9696969696969697, precision: 0.9142857142857143, f_beta: 0.9411764705882354
# train: step: 770, loss: 0.08883710950613022, acc: 0.984375, recall: 0.9830508474576272, precision: 0.9830508474576272, f_beta: 0.9830508474576272
# train: step: 771, loss: 0.16657772660255432, acc: 0.9609375, recall: 0.9508196721311475, precision: 0.9666666666666667, f_beta: 0.9586776859504132
# train: step: 772, loss: 0.11983855068683624, acc: 0.9765625, recall: 0.984375, precision: 0.9692307692307692, f_beta: 0.9767441860465116
# train: step: 773, loss: 0.22417190670967102, acc: 0.90625, recall: 0.8113207547169812, precision: 0.9555555555555556, f_beta: 0.8775510204081634
# train: step: 774, loss: 0.1333397924900055, acc: 0.96875, recall: 0.9491525423728814, precision: 0.9824561403508771, f_beta: 0.9655172413793103
# train: step: 775, loss: 0.11234234273433685, acc: 0.96875, recall: 0.9692307692307692, precision: 0.9692307692307692, f_beta: 0.9692307692307692
# train: step: 776, loss: 0.09409839659929276, acc: 0.9765625, recall: 0.9852941176470589, precision: 0.9710144927536232, f_beta: 0.9781021897810219
# train: step: 777, loss: 0.16091269254684448, acc: 0.953125, recall: 0.967741935483871, precision: 0.9375, f_beta: 0.9523809523809523
# train: step: 778, loss: 0.18320634961128235, acc: 0.953125, recall: 0.971830985915493, precision: 0.9452054794520548, f_beta: 0.9583333333333334
# train: step: 779, loss: 0.17399711906909943, acc: 0.9140625, recall: 0.9230769230769231, precision: 0.9090909090909091, f_beta: 0.9160305343511451
# W0726 14:08:16.673212 140058595800832 deprecation.py:323] From <ipython-input-28-c2e122e5ff6c>:149: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0726 14:08:16.676818 140058595800832 deprecation.py:506] From <ipython-input-28-c2e122e5ff6c>:158: calling SavedModelBuilder.add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# train: step: 780, loss: 0.14672808349132538, acc: 0.9609375, recall: 0.9733333333333334, precision: 0.9605263157894737, f_beta: 0.9668874172185431

# %%
x = "this movie is full of references like mad max ii the wild one and many others the ladybug´s face it´s a clear reference or tribute to peter lorre this movie is a masterpiece we´ll talk much more about in the future"

# 注：下面两个词典要保证和当前加载的模型对应的词典是一致的
with open("../data/wordJson/word2idx.json", "r", encoding="utf-8") as f:
    word2idx = json.load(f)
        
with open("../data/wordJson/label2idx.json", "r", encoding="utf-8") as f:
    label2idx = json.load(f)
idx2label = {value: key for key, value in label2idx.items()}
    
xIds = [word2idx.get(item, word2idx["UNK"]) for item in x.split(" ")]
if len(xIds) >= config.sequenceLength:
    xIds = xIds[:config.sequenceLength]
else:
    xIds = xIds + [word2idx["PAD"]] * (config.sequenceLength - len(xIds))

graph = tf.Graph()
with graph.as_default():
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
    session_conf = tf.ConfigProto(allow_soft_placement=True, log_device_placement=False, gpu_options=gpu_options)
    sess = tf.Session(config=session_conf)

    with sess.as_default():
        checkpoint_file = tf.train.latest_checkpoint("../model")
        saver = tf.train.import_meta_graph("{}.meta".format(checkpoint_file))
        saver.restore(sess, checkpoint_file)

        # 获得需要喂给模型的参数，输出的结果依赖的输入值
        inputX = graph.get_operation_by_name("inputX").outputs[0]
        dropoutKeepProb = graph.get_operation_by_name("dropoutKeepProb").outputs[0]

        # 获得输出的结果
        predictions = graph.get_tensor_by_name("output/predictions:0")

        pred = sess.run(predictions, feed_dict={inputX: [xIds], dropoutKeepProb: 1.0})[0]
        
pred = [idx2label[item] for item in pred]     
print(pred)
# Out:
# W0726 14:13:23.752521 140058595800832 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# ['1']
